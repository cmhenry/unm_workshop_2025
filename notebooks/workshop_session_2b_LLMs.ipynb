# %% [markdown]
# # LLMs in Political Science Research via API
#
# ## Session 2 - Working with LLMs via API
#
# Through practical examples, we will explore prompt engineering techniques for tasks such as concept mining and named entity recognition in textual data.
#
# ## Session Outline
#
# - **Prompt Engineering**: Techniques for crafting effective prompts to guide LLMs in generating relevant and accurate responses.
# - **Concept Mining**: Using LLMs to extract key concepts from text, enabling researchers to identify important themes and ideas.
# - **Named Entity Recognition (NER)**: Implementing NER to identify and classify entities in text, such as people, organizations, and locations.

# %% [markdown]
# ## UNM 2025 Workshop Data
#
# Before we start exploring the API, let's take a look at the corpus of documents we will be working.
#
# **Repository:** https://github.com/LNB-DH/BSSDH_2025_workshop_data
#
#
#
#
# ## CORPUS OVERVIEW
#
#
# 1. SOURCE MATERIAL
# ------------------
#
# | Periodical | Details |
# |------------|---------|
# | "Rigasche Zeitung" (RZei) (1918–1919) | - **Data file:** `Rigasche_Zeitung_1918_1919.zip`<br>- **Download Rigasche Zeitung:** https://github.com/LNB-DH/BSSDH_2025_workshop_data/raw/main/data/Rigasche_Zeitung_1918_1919.zip<br>- Morning newspaper, intermittently published from 1778 to 1919 in Riga.<br>- Language: German (Fraktur script)<br>- Once the most popular morning paper in the Baltic provinces of the Russian Empire.<br>- Covered general political and economic news in Riga, the Baltics, the Russian Empire, and internationally.<br>- Historical context: World War I, Latvian War of Independence.<br>- Link: https://periodika.lv/#periodicalMeta:234;-1<br>- More info: https://enciklopedija.lv/skirklis/163962 |
# | "Latvian Economic Review" (LERQ) (1936–1940) | - **Data file:** `Latvian_Economic_Review_1936_1940.zip`<br>- **Download Latvian Economic Review:** https://github.com/LNB-DH/BSSDH_2025_workshop_data/raw/main/data/Latvian_Economic_Review_1936_1940.zip<br>- Full title: "Latvian Economic Review: A quarterly review of trade, industry and agriculture".<br>- Language: English (modern)<br>- Published by the Latvian Chamber of Commerce and Industry (established 1934).<br>- Focused on cross-border representation of Latvian economy during the Great Depression, increasing state control, push for autarky, and start of WWII.<br>- Link: https://periodika.lv/#periodicalItem:620 |
#
# 2. CORPUS INFORMATION
# ----------------------
#
# | Metric | RZei | LERQ |
# |--------|------|------|
# | Token Count (words) | 5.37 million | 0.5 million |
# | Issue Count | 359 issues | 18 issues |
# | Segment (Article <=> File) Count | 4,597 | 419 |
# | Language | German | English |
# | Script | Fraktur | Modern |
#
# Filename Structure:
# -------------------
# Format: [periodical][year][volume#*][issue#]_[page#]_[[plaintext]]_[segment#]
#
# Example: `lerq1936s01n02_031_plaintext_s17.txt`
#          → 17th segment from LERQ, Issue 2, 1936, page 31.
#
# *Volume value in corpus is one in all cases.
#
# 3. METHODOLOGY
# ---------------
#
# | Step | Description |
# |------|-------------|
# | 3.1. Source Access | Digitised issues obtained from the National Library of Latvia (https://periodika.lv/) |
# | 3.2. Processing & OCR | CCS docWORKS & ABBYY FineReader 9.0<br>- LERQ has better OCR quality than RZei<br>- No further data cleaning/normalization |
# | 3.3. Metadata Added | Fields: title, author, uri<br>- Author info available in:<br>&nbsp;&nbsp;&nbsp;&nbsp;LERQ: 4 cases (0.95%)<br>&nbsp;&nbsp;&nbsp;&nbsp;RZei: 325 cases (7.05%)<br>- Title availability:<br>&nbsp;&nbsp;&nbsp;&nbsp;LERQ: 95.7%, RZei: 99.15%<br>- URI coverage: 100% for both<br>- URIs point to LNB DOM system |

# %% [markdown]
# ## Extracting documents
#
# We could extract documents manually by downloading the appropriate zip file and extracting files by *hand* using file extracting capabilities built into your Operating System (Windows has built in extractor) or using external program such as 7-zip, WinRAR, etc. However, it is more replicable and convenient to use a script that will do this for us. We would supply a url or file name and the script would download the file, extract it to approparite location, and return a list of files that were extracted.
#
# ### Additional considerations when extracting documents
#
# * Where will be extracted files be stored? - Ideally we would have a same relative structure when extracting files locally and on remote server such as Google Colab.
# * How will we handle file names? - Usually we would like to keep the original file names, but we might want to add some additional information such as source or date of extraction.
# * How will we handle errors? - We should consider what to do if the file cannot be downloaded or extracted. Should we skip it or raise an error?
#
# ### Extracting Latvian Economic Review
#
# For this session we will extract Latvian Economic Review (LERQ) corpus. We will use a script that will download the file, extract it to appropriate location, and return a list of files that were extracted.
#
# We will write a function in Python that will do this for us. The function will take a URL or file name as an argument and will download file from url and then extract it. We will have a default location where the files will be extracted, but we can also specify a different location if needed.
#
# ```python

# %%
url = "https://github.com/LNB-DH/BSSDH_2025_workshop_data/raw/main/data/Latvian_Economic_Review_1936_1940.zip"
print("Will extract data from", url)
# next we define a function that will download and extract the zip file, this way we can reuse it later if needed
# we can also set some default values for the arguments, so we do not have to specify
# default values always come after the mandatory arguments in Python functions
def extract_zip(url, output_dir="data", verbose=False):
    # we could have imported these at the top, but we want to keep the script self-contained
    import requests  # this should be cached by notebooks, so it **should** not require importing it every time
    from zipfile import ZipFile
    from io import BytesIO

    # In verbose mode let's some extra information about the download and extraction process
    # This is useful for debugging and understanding the flow of the script
    from datetime import datetime
    if verbose:
        download_start = datetime.now()
        # we print start time including milliseconds
        print(f"Starting download at {download_start.strftime('%Y-%m-%d %H:%M:%S.%f')}")
        print("Starting download from", url)
    response = requests.get(url)
    if verbose:
        download_finish = datetime.now()
        print(f"Download finished at {download_finish.strftime('%Y-%m-%d %H:%M:%S.%f')} taking {download_finish - download_start} seconds")
    if response.status_code == 200: # it is possible a request fails, e.g. if the URL is incorrect
        if verbose:
            extract_start = datetime.now()
            print(f"Starting extraction to {output_dir} at {extract_start.strftime('%Y-%m-%d %H:%M:%S.%f')}")
        with ZipFile(BytesIO(response.content)) as zf:
            zf.extractall(output_dir)
        if verbose:
            extract_end = datetime.now()
            print(f"Extraction finished at {extract_end.strftime('%Y-%m-%d %H:%M:%S.%f')} taking {extract_end - extract_start} seconds")
            print(f"Total time taken: {extract_end - download_start} seconds")
    else:
        print("Failed to download data:", response.status_code)

# now that we have our function defined, we can call it immediately
# note we do not supply all arguments, first one is mandatory, the rest are optional
# so we skip over output_dir in this case
extract_zip(url, verbose=True)
# Out:
# Will extract data from https://github.com/LNB-DH/BSSDH_2025_workshop_data/raw/main/data/Latvian_Economic_Review_1936_1940.zip
# Starting download at 2025-09-05 15:08:49.630621
# Starting download from https://github.com/LNB-DH/BSSDH_2025_workshop_data/raw/main/data/Latvian_Economic_Review_1936_1940.zip
# Download finished at 2025-09-05 15:08:50.091615 taking 0:00:00.460994 seconds
# Starting extraction to data at 2025-09-05 15:08:50.092022
# Extraction finished at 2025-09-05 15:08:50.181857 taking 0:00:00.089835 seconds
# Total time taken: 0:00:00.551236 seconds

# %% [markdown]
# ### Getting information about extracted files
#
# It is a good practice to double check what files were extracted and where they are located. We can do this by listing the files in the directory where we extracted them. We can use Python pathlib to do this.
# The goal is to double check that what we extacted matches what we expected. We can also check the file names and their structure to make sure they are correct.
#
# ```python

# %%
from pathlib import Path
extract_dir = Path("data") # note this is a a relative path, relative to the current working directory for the notebook
# let's check if the directory exists and how many files it contains
if extract_dir.exists():
    files = list(extract_dir.glob("*"))  # this will list all files in the directory
    print(f"Extracted {len(files)} files to {extract_dir}")
    for file in files:
        print(file.name)  # print the name of each file
else:
    print(f"Directory {extract_dir} does not exist. Please check the extraction process.")
# Out:
# Extracted 1 files to data
# Latvian_Economic_Review

# %% [markdown]
# ### Getting information about subfolders in the extracted directory
# Looks like we only have a single file but it is actually not a file but a directory. This is because we extracted a zip file that contains files under a single directory.
#
# Next we want to check how many total files we have and also how many files we have with *.txt extension. This will help us to understand how many files we can work with and if there are any files that we might want to exclude from our analysis.

# %%
# let's check how many files total we have and how many files with *.txt extension counting all subfolders
# this means we will perform a recursive search for all files in the directory

def analyze_directory_contents(directory_path, verbose=True):
    """
    Analyze the contents of a directory recursively and provide detailed information.

    Args:
        directory_path: Path object or string path to the directory
        verbose: If True, print detailed information about file types and structure

    Returns:
        dict: Dictionary containing analysis results
    """
    from pathlib import Path

    directory = Path(directory_path)

    if not directory.exists():
        print(f"Directory {directory} does not exist.")
        return None

    # Get all files recursively
    all_files = list(directory.rglob("*"))

    # Separate files from directories
    files_only = [f for f in all_files if f.is_file()]
    directories_only = [f for f in all_files if f.is_dir()]

    # Count files by extension
    file_extensions = {}
    for file in files_only:
        ext = file.suffix.lower()
        if ext == '':
            ext = '(no extension)'
        file_extensions[ext] = file_extensions.get(ext, 0) + 1

    # Count .txt files specifically
    txt_files = [f for f in files_only if f.suffix.lower() == '.txt']

    # Analysis results
    results = {
        'total_items': len(all_files),
        'total_files': len(files_only),
        'total_directories': len(directories_only),
        'txt_files': len(txt_files),
        'file_extensions': file_extensions,
        'txt_file_paths': txt_files
    }

    if verbose:
        print(f"📁 Directory Analysis: {directory}")
        print("=" * 50)
        print(f"Total items found (files + directories): {results['total_items']}")
        print(f"Total files: {results['total_files']}")
        print(f"Total directories: {results['total_directories']}")
        print(f"Text files (.txt): {results['txt_files']}")
        print()

        print("📊 File Extensions Summary:")
        print("-" * 30)
        for ext, count in sorted(file_extensions.items(), key=lambda x: x[1], reverse=True):
            print(f"  {ext}: {count} files")
        print()

        if len(directories_only) > 0:
            print("📂 Directory Structure:")
            print("-" * 30)
            for directory in sorted(directories_only):
                # Show relative path from the base directory
                relative_path = directory.relative_to(directory_path)
                print(f"  📁 {relative_path}")
            print()

        if len(txt_files) > 0 and len(txt_files) <= 10:
            print("📄 Sample .txt files:")
            print("-" * 30)
            for txt_file in sorted(txt_files)[:10]:
                relative_path = txt_file.relative_to(directory_path)
                file_size = txt_file.stat().st_size
                print(f"  📄 {relative_path} ({file_size:,} bytes)")
        elif len(txt_files) > 10:
            print(f"📄 First 10 .txt files (out of {len(txt_files)} total):")
            print("-" * 30)
            for txt_file in sorted(txt_files)[:10]:
                relative_path = txt_file.relative_to(directory_path)
                file_size = txt_file.stat().st_size
                print(f"  📄 {relative_path} ({file_size:,} bytes)")
            print(f"  ... and {len(txt_files) - 10} more .txt files")

    return results

# Now let's analyze our extracted directory
print("Analyzing extracted data directory...")
analysis_results = analyze_directory_contents(extract_dir, verbose=True)
# Out:
# Analyzing extracted data directory...
# 📁 Directory Analysis: data
# ==================================================
# Total items found (files + directories): 420
# Total files: 419
# Total directories: 1
# Text files (.txt): 419
#
# 📊 File Extensions Summary:
# ------------------------------
#   .txt: 419 files
#
# 📂 Directory Structure:
# ------------------------------
#   📁 Latvian_Economic_Review
#
# 📄 First 10 .txt files (out of 419 total):
# ------------------------------
#   📄 Latvian_Economic_Review/lerq1936s01n01_003_plaintext_s01.txt (8,662 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_006_plaintext_s02.txt (5,190 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_008_plaintext_s03.txt (6,066 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_009_plaintext_s04.txt (5,523 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_013_plaintext_s05.txt (3,866 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_014_plaintext_s06.txt (1,144 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_014_plaintext_s07.txt (629 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_015_plaintext_s08.txt (7,520 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_017_plaintext_s09.txt (951 bytes)
#   📄 Latvian_Economic_Review/lerq1936s01n01_018_plaintext_s10.txt (7,625 bytes)
#   ... and 409 more .txt files

# %%
# let's get 8th text file from analysis_results dictionary text_files_paths key
text_files_list = sorted(analysis_results['txt_file_paths'])
if len(text_files_list) >= 8:
    eighth_text_file = text_files_list[7]  # 8th file, index starts from 0
    print(f"8th text file: {eighth_text_file.name} ({eighth_text_file.stat().st_size:,} bytes)")
# Out:
# 8th text file: lerq1936s01n01_015_plaintext_s08.txt (7,520 bytes)

# %%
# let's print out its contents
with eighth_text_file.open('r', encoding='utf-8') as f:
    content = f.read() # read whole file content into memory
# file is closed here automatically due to the with statement
print(f"Contents of {eighth_text_file.name}:\n")
print(content[:500])  # print first 500 characters to avoid too much output
print("\n... (truncated output)")
# Out:
# Contents of lerq1936s01n01_015_plaintext_s08.txt:
#
# title: Central Union of Latvian Cooperative Dairy Societies
# author:
# uri: http://dom.lndb.lv/data/obj/159411
#
#
#
# The central union of Latvian Cooperative dairy
# societies, established in August 1921, is the only
# central organisation for promoting the dairy industry
# in this country. It was founded by 13 of the 18
# dairy societies then in existence. The number of
# members has increased considerably in the meantime,
# totalling at present 208 of the 289 dairy societies in
# operation, or 72% of the coopera
#
# ... (truncated output)

# %% [markdown]
# ## Setting up our LLM API functions

# %%
#  we will prompt user to enter it manually if not found
import getpass

import os # we already imported this, but let's do it again for clarity - it is cached so no harm done


# if still not found, prompt user to enter it manually
if 'open_router_api_key' not in locals() or not open_router_api_key:
    open_router_api_key = getpass.getpass("Please enter your OpenRouter API key: ")
    # save it to .env file for future use
    # note Google Colab will destroy .env file after session ends, so you will need to enter it again next time
    # this can be useful if you re-run the notebook and want to avoid entering the key again
    print("Saving Open Router API key to .env file...")
    with open('.env', 'a') as f:
        f.write(f'OPENROUTER_API_KEY={open_router_api_key}\n')
    print("Open Router API key saved to .env file.")

# we now should have the OpenRouter API key available
if open_router_api_key:
    print("OpenRouter API key loaded successfully.")
else:
    print("OpenRouter API key not found. Please make sure you have it set in your environment variables or .env file.")
    print("You can also enter it manually when prompted during API calls.")

# key point we do not print it publicly it is stored as a variable under the name open_router_api_key - of course you can change the name to something more descriptive
# but do not print it to the console or logs, as it is sensitive information
# Out:
# Please enter your OpenRouter API key: ··········
# Saving Open Router API key to .env file...
# Open Router API key saved to .env file.
# OpenRouter API key loaded successfully.

# %% [markdown]
# ### About the model - Google: Gemini 2.5 Flash Lite
#
# Unlike previous session where we used OpenAI API, this session will focus on using [Google Gemini 2.5 Flash Lite model](https://openrouter.ai/google/gemini-2.5-flash-lite) via OpenRouter API. Again we could have used many different models, but we will use this one as it is lightweight and fast and **INEXPENSIVE**, which is ideal for our use case.
#
# **Model ID:** `google/gemini-2.5-flash-lite`
# **Created:** July 22, 2025
# **Context Window:** 1,048,576 tokens
# **Pricing:**
# - **Input tokens:** $0.10 per million
# - **Output tokens:** $0.40 per million
#
# **Tags:**
# - Legal (#4)
# - Marketing/SEO (#4)
# - Translation (#9)
#
# **Description:**
# Gemini 2.5 Flash Lite is a lightweight reasoning model in the Gemini 2.5 family, optimized for **ultra-low latency** and **cost efficiency**. It offers improved throughput, faster token generation, and better performance across common benchmarks compared to earlier Flash models.
#
# By default, "thinking" (i.e., multi-pass reasoning) is disabled to prioritize speed, but developers can enable it via the **Reasoning API** parameter to selectively trade off cost for intelligence.

# %%
# let's define a generic function for OpenRouter API requests
# it should define a new function get_openrouter_response with the following parameters system_prompt, user_prompt,
#  model defaulting to google/gemini-2.5-flash-lite and finally api_key which defaults to open_router_api_key .
#  The function get_openrouter_response should function just like analyze_latvian_text_with_openrouter except with parameters.
import requests  # we need to import requests to make API calls

def get_openrouter_response(system_prompt, user_prompt,
                            model="google/gemini-2.5-flash-lite",
                            api_key=open_router_api_key,
                            max_tokens=4096,
                            temperature=0.5,):
    """
    Generic function to make requests to OpenRouter API with specified parameters.

    :param system_prompt: The system prompt to guide the model's behavior.
    :param user_prompt: The user query or text to analyze.
    :param model: The model to use for the request (default is GPT-3.5).
    :param api_key: The OpenRouter API key (default is loaded from environment).
    :return: The response from the OpenRouter API.
    """

    # Set up the API endpoint and headers
    url = "https://openrouter.ai/api/v1/chat/completions"

    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json",
        "HTTP-Referer": "https://github.com/cmhenry/unm_workshop_2025",  # Your project URL
        "X-Title": "UNM 2025 LLM Workshop - Generic OpenRouter Request"
    }

    # Create the request payload
    request_data = {
        "model": model,
        "messages": [
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        "max_tokens": max_tokens,
        "temperature": temperature,
        "top_p": 0.9
    }

    # Make the API request
    try:
        response = requests.post(url, headers=headers, json=request_data, timeout=30)
        response.raise_for_status()

        result = response.json()

        if 'choices' in result and len(result['choices']) > 0:
            return result['choices'][0]['message']['content']

        else:
            print("❌ Error: No response returned from the API")
            return None

    except requests.exceptions.RequestException as e:
        print(f"❌ Request Error: {e}")
        return None

system_prompt = """You are a political science researcher specializing in named entity recognition and text analysis.
Named entities are cities, persons, organizations, etc. that are mentioned in the text.
You will analyze the text and provide all named entities as a list."""
user_prompt = content

response = get_openrouter_response(system_prompt, user_prompt) # note we did not pass model or api_key, so it will use defaults of "openai/gpt-3.5-turbo" and open_router_api_key

if response:
    print("Response from OpenRouter API:")
    print(response)
else:
    print("Failed to get a response from OpenRouter API.")
# Out:
# Response from OpenRouter API:
# * Central Union of Latvian Cooperative Dairy Societies
# * Latvia
# * P/S „Latvijas centralais sviesta eksports" (United Butter Export of Latvia, Ltd.)
# * Ministry of Agriculture
# * Riga
# * Latvian University
# * Riga Strand

# %% [markdown]
# ## Adjusting system prompts
#
# We got our named entities but let's also have categories for them.
# We can do that by adjusting our system prompt to include categories for named entities.

# %%
# let's adjust our system prompt by adding extra instruction to add categories for named entities.
extra_instruction = "Please categorize the named entities into PERSON, ORGANIZATION, LOCATION, and MISC."
system_prompt = f"{system_prompt} {extra_instruction}"
print(f"Adjusted system prompt: {system_prompt}")
# Out:
# Adjusted system prompt: You are a political science researcher specializing in named entity recognition and text analysis.
# Named entities are cities, persons, organizations, etc. that are mentioned in the text.
# You will analyze the text and provide all named entities as a list. Please categorize the named entities into PERSON, ORGANIZATION, LOCATION, and MISC.

# %%
# let's see our response with adjusted system prompt
response = get_openrouter_response(system_prompt, user_prompt)
if response:
    print("Response with adjusted system prompt:")
    print(response)
# Out:
# Response with adjusted system prompt:
# Here's a breakdown of the named entities in the text:
#
# **ORGANIZATION**
#
# *   Central Union of Latvian Cooperative Dairy Societies
# *   P/S „Latvijas centralais sviesta eksports" (United Butter Export of Latvia, Ltd.)
# *   Ministry of Agriculture
# *   microbiological institute of the Latvian University
#
# **LOCATION**
#
# *   Latvia
# *   Riga
#
# **MISC**
#
# *   Ls (Latvian currency unit)

# %% [markdown]
# ## Getting a summary of the text
#
# One of the basic tasks we can do with LLMs is to get a summary of the text.

# %%
summary_system_prompt = """You are a political science researcher specializing in text summarization.
You will summarize the text and provide a concise summary in structured bullet point format."""
response = get_openrouter_response(summary_system_prompt, content)
if response:
    print("Summary of the text:")
    print(response)
# Out:
# Summary of the text:
# Here's a summary of the provided text about the Central Union of Latvian Cooperative Dairy Societies:
#
# *   **Establishment and Membership:** Founded in August 1921 by 13 dairy societies, it is the sole central organization for Latvia's dairy industry. It currently represents 72% of the nation's dairy societies (208 out of 289). Membership has decreased due to the world depression and low dairy prices, leading smaller dairies to merge.
#
# *   **Butter Export and Marketing:** The Union has been successful in promoting butter exports and local consumption. Up to the end of 1934, it facilitated the sale of nearly 95 million kg of butter. In late 1934, a government-backed share company, P/S „Latvijas centralais sviesta eksports" (United Butter Export of Latvia, Ltd.), was formed for dairy export marketing. The Central Union owns 67% of this company, which handles the sole export and local marketing rights for Latvian dairy products.
#
# *   **Supply and Development Activities:** The Central Union extends the network of cooperative dairies and supplies them with essential materials like machinery, salt, and cattle fodder. It plans to expand this supply role to other agricultural sectors, especially given foreign trade restrictions affecting smaller suppliers.
#
# *   **Import and Turnover:** The Union is a significant Latvian importer, with its turnover increasing substantially, from Ls 0.51 million in 1934 to Ls 1.2 million in the first quarter of 1935.
#
# *   **Riga Milk Central:** Established in 1927, the Riga milk central supplies the capital with fresh milk and dairy products. In 1934, it processed over 8 million kg of milk and 569,000 kg of cream, with products subject to daily quality checks. The central operates its own shops and uses a fleet of vehicles for delivery to institutions and over 1000 provision shops. Its sales have shown consistent year-on-year growth.
#
# *   **By-product Manufacturing:** A new chemical factory was opened in July 1934 to manufacture by-products such as casein and casein dyes.
#
# *   **Financial Resources:** The Union's resources, derived from entrance fees, share capital, and accumulated funds, have grown significantly. By January 1, 1935, its capital was Ls 1.534 million, a tenfold increase from Ls 153,000 in 1925.
#
# *   **Advisory and Educational Work:** The Central Union provides advisory and educational services to dairies through its instructors, offering guidance on production, management, and bookkeeping.
#
# *   **Organizational Structure:** The Union represents farmers through their dairy societies. Its supreme administrative body is the assembly of authorized representatives, which elects a council and a board responsible for administration and business. The board acts as a crucial link between rural producers and urban consumers.

# %% [markdown]
# ## Concept mining
#
# For those are unfamiliar with the term, concept mining is a process of extracting key concepts from a text.
#
# Concept mining involves automatically identifying and extracting abstract ideas or key concepts from large amounts of unstructured text data. It goes beyond surface-level keyword extraction by attempting to detect the underlying themes, topics, or conceptual entities present in the text -- including those that might not be explicitly named but are implied or paraphrased.
#
# Example would be "the rise of the internet" instead of just "internet". Instead of "potatoes" we could extract "agricultural products" or "food production". Something like "food anxiety" instead of just "food".

# %%
# let's make a system prompt for concept mining
system_prompt = """You are a political science researcher specializing in concept mining.
You will analyze the text and extract key concepts, themes, and patterns as a structured list.
Please provide the concepts in a clear and concise manner, categorizing them into relevant themes."""
response = get_openrouter_response(system_prompt, content)
if response:
    print("Concepts extracted from the text:")
    print(response)
# Out:
# Concepts extracted from the text:
# Here are the key concepts, themes, and patterns extracted from the provided text, categorized for clarity:
#
# **I. Organizational Structure and History**
#
# *   **Establishment:** Founded in August 1921.
# *   **Founding Members:** 13 out of 18 existing dairy societies.
# *   **Current Membership:** 208 out of 289 dairy societies (72% of the cooperative dairy industry).
# *   **Purpose:** Sole central organization for promoting the dairy industry in Latvia.
# *   **Administrative Organs:**
#     *   Assembly of authorized representatives (supreme administrative organ).
#     *   Council (15 members, elected by the assembly).
#     *   Board (Chairman and four members, elected from the council, administers property and conducts business).
# *   **Role as a Link:** Connects the countryside (farmers) and the metropolis (consumers).
#
# **II. Economic Context and Challenges**
#
# *   **World Depression:** Impacted membership due to decreased dairy societies.
# *   **Low Butter Prices:** Adverse circumstances leading to consolidation of smaller dairies.
# *   **Foreign Trade Restrictions:** Impeding regular supply of agricultural goods.
# *   **Adverse Economic Conditions:** Mentioned in relation to resource growth despite challenges.
#
# **III. Core Activities and Services**
#
# *   **Dairy Industry Promotion:** Central role in advancing the sector.
# *   **Export Facilitation & Augmentation:**
#     *   Successful in facilitating and augmenting butter export.
#     *   Established P/S „Latvijas centralais sviesta eksports" (United Butter Export of Latvia, Ltd.) in 1934.
#     *   Owns 67% of shares in the export company.
#     *   Products constitute over 80% of the export company's turnover.
# *   **Local Market Promotion:**
#     *   Promoting butter consumption in the local market.
#     *   Sole local marketing rights for dairy products through the export company.
# *   **Cooperative Development:**
#     *   Extending the network of cooperative dairies.
#     *   Supplying dairies with essential materials:
#         *   Dairy machinery and utensils.
#         *   Salt, vegetable parchment, staves for casks.
#         *   Cattle fodder, ironware, fertilisers.
# *   **Agricultural Supply Chain:**
#     *   Intends to supply goods for other branches of agriculture.
#     *   Undertaking distribution of agricultural machinery, petroleum, lubricating oil, Colonial goods, and other requisites due to foreign trade restrictions.
# *   **Riga Milk Central Operations (established 1927):**
#     *   Supplying the metropolis with fresh milk and high-quality dairy products.
#     *   Daily examination of products by the microbiological institute of the Latvian University.
#     *   Modern pasteurizing and processing machinery.
#     *   Processing large quantities of milk and cream.
#     *   Products: Fresh milk, pasteurized milk, fresh and sour cream, kefir, cheese, toffee.
# *   **Retail Operations:**
#     *   Maintaining own shops for milk and dairy product supply.
#     *   Extensive delivery network (carts, motor lorries) to institutions and provision shops.
# *   **By-product Manufacturing:**
#     *   Opened a chemical factory (July 1934) for casein, galalith, casein dyes, etc.
#
# **IV. Financial and Resource Aspects**
#
# *   **Resources:** Members' entrance fees, share capital, accumulated funds.
# *   **Resource Growth:** Rapid increase in resources, representing 41.8% of the balance sheet in 1935.
# *   **Capital Growth:** Tenfold increase in capital from Ls 153,000 (1925) to Ls 1,534,000 (1935).
# *   **Turnover Growth:**
#     *   Increasing steadily in imports.
#     *   Riga Milk Central turnover increasing year-on-year.
# *   **Sales Figures (Examples):**
#     *   Butter sales abroad and at home (up to end of 1934): ~95 million kg for Ls 253,496,000.
#     *   Riga Milk Central sales: Ls 2,011,000 (1932) to Ls 2,672,000 (1934).
#     *   Imports: Ls 0.51 million (1934) to Ls 1.2 million (Q1 1935).
#
# **V. Advisory and Educational Role**
#
# *   **Advisory Work:** Providing advice and instruction to dairies.
# *   **Educational Work:**
#     *   Executed by a staff of instructors.
#     *   Focus areas: Production, management, and bookkeeping.
#
# **VI. Key Partnerships and Government Relations**
#
# *   **Government Concurrence:** Establishment of the export organization in concurrence with the Government.
# *   **Government Sanction:** New export company's statutes sanctioned by the Cabinet.
# *   **Ministry of Agriculture Supervision:** Four butter firms (shareholders of the export company) are under its supervision.
# *   **Latvian University:** Microbiological institute examines products from the Riga Milk Central.
#
# **VII. Market Position and Influence**
#
# *   **Dominant Player:** The Central Union is the largest and most important enterprise in supplying dairies with materials (over 90%).
# *   **Prominent Importer:** Figures prominently in the list of Latvian importers.
# *   **Market Representative:** Represents the producers themselves (farmers).
#
# **VIII. Specific Products and By-products**
#
# *   **Dairy Products:** Butter, milk, cream, kefir, cheese, toffee.
# *   **By-products:** Casein, galalith, casein dyes.

# %% [markdown]
# ## 🧠 Concept Categories for 1930s Latvian Economic Reports
#
# Above LLM output gave us structured but still flexible list of concepts. Usually we want to focus on a specific set of concepts that are relevant to our research. Below is a list of categories that we can use to organize the concepts extracted from the 1930s Latvian Economic Reports.
#
# ### 🏦 Finance & Banking
# - Financial stability
# - Monetary policy
# - Currency regulation
# - Exchange rates
# - Foreign investment
# - Credit availability
# - Central banking
# - Gold reserves
#
# ### 📈 Trade & Commerce
# - Trade liberalization
# - Export promotion
# - Import substitution
# - Customs tariffs
# - Balance of trade
# - Foreign trade agreements
# - Trade protectionism
# - Trade surplus/deficit
# - Transit trade
# - Port activity (e.g., Riga, Liepāja)
#
# ### 🚜 Agriculture & Rural Economy
# - Agricultural modernization
# - Land reform
# - Crop yields
# - Agricultural exports
# - Collective farming (if present)
# - Peasant cooperatives
# - Grain storage and reserves
# - Rural credit
# - Mechanization of agriculture
# - Dairy and livestock production
#
# ### 🏭 Industry & Infrastructure
# - Industrialization
# - Manufacturing output
# - Raw material imports
# - Industrial policy
# - State-owned enterprises
# - Energy production (electricity, fuel)
# - Infrastructure investment
# - Transportation development
# - Railway modernization
# - Telecommunications expansion
#
# ### 👷 Labor & Employment
# - Unemployment
# - Labor migration
# - Wages and cost of living
# - Labor policy
# - Social insurance
# - Vocational training
# - Workforce productivity
# - State employment programs
#
# ### 💰 Prices & Markets
# - Price stability
# - Inflation control
# - Consumer goods availability
# - Market regulation
# - Food pricing
# - Speculation control
#
# ### 🏛️ Economic Policy & Governance
# - Five-year plans (if applicable)
# - Corporatism
# - Authoritarian economic planning
# - State intervention
# - Public-private partnerships
# - Fiscal policy
# - Budget deficit
# - Taxation policy
# - Economic nationalism
#
# ### 🌍 International Relations & Geopolitics
# - Trade with Germany, USSR, UK, Sweden, etc.
# - Regional trade blocs (e.g., Baltic Entente)
# - Neutrality in foreign policy
# - Geopolitical pressures on trade
# - Sanctions or economic treaties
#
# ### 🧑‍🏫 Education & Human Capital
# - Economic education
# - Technical schools
# - Business training
# - Scientific research for industry
# - Demographic skills gap
#
# ### 🧱 Development & Urbanization
# - Urban planning
# - Rural-urban migration
# - Public works
# - Housing policy
# - Regional economic disparity
# - Municipal finance
#
# ---
#
# ### 🎯 High-Level & Cross-Cutting Concepts
# - Economic self-sufficiency
# - National economic strategy
# - Resilience to global crisis
# - Preparation for war economy
# - Currency sovereignty
# - Export dependency
# - Shadow economy (if mentioned)

# %% [markdown]
# ## Focusing on specific concepts - agriculture
#
# For this workshop let's focus on the agriculture category. We will extract concepts related to agriculture from the 1930s Latvian Economic Reports and analyze them in more detail.
#
# ### Making a larger system prompt
#
# Our system prompt will be a bit more complex as we want to mention the specific category we are interested in. Also we want to provide example of format that we want the LLM to return so our analysis will be more structured and easier to work with.

# %%
agriculture_system_prompt = """You are an expert assistant trained to analyze historical economic texts from 1930s Latvia.
Your task is to read the input document or paragraph and extract any **concepts** that relate specifically to the domain of **Agriculture & Rural Economy**.
Focus only on concepts connected to the following subcategories:
- Agricultural modernization
- Land reform
- Crop yields
- Agricultural exports
- Collective farming (if present)
- Peasant cooperatives
- Grain storage and reserves
- Rural credit
- Mechanization of agriculture
- Dairy and livestock production
- Other agricultural practices

For each concept you extract, return:
- The **exact phrase** or **paraphrased expression** found in the text
- A **brief explanation** (1–2 sentences) summarizing the concept’s meaning or context
- The most relevant **subcategory** from the list above that it matches

Only return relevant agricultural or rural economy concepts. If no relevant concept is found, return an empty list.

Use the following output format (in JSON):

[
  {
    "phrase": "introduction of American tractors",
    "explanation": "Refers to adoption of mechanized equipment to improve farming productivity.",
    "subcategory": "Mechanization of agriculture"
  },
  {
    "phrase": "state-supported grain warehouses",
    "explanation": "Refers to government involvement in securing grain storage for future needs or trade.",
    "subcategory": "Grain storage and reserves"
  }
]
"""

response = get_openrouter_response(agriculture_system_prompt, content)
if response:
    print("Agriculture-related concepts extracted from the text:")
    print(response)
# Out:
# Agriculture-related concepts extracted from the text:
# ```json
# [
#   {
#     "phrase": "promoting the dairy industry",
#     "explanation": "Focuses on the development and advancement of dairy farming and related businesses.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "low prices fetched by dairy products in the world market",
#     "explanation": "Indicates the impact of global market conditions on the profitability of dairy farming.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "facilitate and augment the export of butter",
#     "explanation": "Refers to efforts to increase the volume and ease of selling butter to foreign markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "promoting the consumption of this commodity in the local market",
#     "explanation": "Describes activities aimed at increasing the sales of dairy products within the country.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "special organisation for exporting dairy produce was established by the Government, in concurrence with the Central Union",
#     "explanation": "Highlights government and cooperative efforts to streamline and manage the export of dairy products.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "supplying them with dairy machinery, utensils, salt, vegetable parchment, staves for casks, cattle fodder, ironware, fertilisers and other materials",
#     "explanation": "Details the provision of essential inputs and equipment to cooperative dairies to support their operations.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "supplying farmers with agricultural machinery, petroleum, lubricating oil, Colonial goods and other requisites",
#     "explanation": "Describes the provision of various supplies and equipment necessary for farming operations.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "supplying the metropolis with fresh milk and high quality dairy products",
#     "explanation": "Focuses on the distribution of fresh milk and other dairy goods to urban consumers.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "milk central in Riga ... equipped with modern machinery for pasteurizing and working up the large quantities of milk",
#     "explanation": "Describes the use of advanced technology in processing milk for public consumption.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "manufacturing of various by-products such as casein, galalith, casein dyes etc.",
#     "explanation": "Refers to the processing of milk by-products into valuable materials and chemicals.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "give advice and instruction in matters pertaining to production, management and bookkeeping",
#     "explanation": "Highlights advisory and educational services provided to dairies to improve their operations and financial management.",
#     "subcategory": "Other agricultural practices"
#   }
# ]
# ```

# %% [markdown]
# ## Fine-tuning the system prompt and adjusting model
#
# The LLM output is well structured and clear concepts are extracted -- but what if we wanted to adjust our system prompt to be more specific about the concepts we want to extract?
#
#  We can also adjust the model or its parameters to be more focused on the specific task we are trying to achieve. For example, we can increase the maximum number of tokens to allow for more detailed responses or adjust the temperature to make the model more conservative in its responses.

# %%
### let's try a different model first - let's try the best (and most expensive) current Gemini model as of mid 2025 - 2.5 Pro

response = get_openrouter_response(agriculture_system_prompt, content, model="google/gemini-2.5-pro")
if response:
    print("Agriculture-related concepts extracted from the text using Gemini 2.5 Pro:")
    print(response)
# Out:
# Agriculture-related concepts extracted from the text using Gemini 2.5 Pro:
# ```json
# [
#   {
#     "phrase": "central union of Latvian Cooperative dairy societies",
#     "explanation": "This refers to the central organization representing and coordinating the activities of numerous local cooperative dairy societies, which were owned by farmers.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "smaller dairies to join together and form larger units",
#     "explanation": "This describes a trend of consolidation among dairy cooperatives to improve product quality and reduce production costs in response to economic pressures.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "facilitate and augment the export of butter",
#     "explanation": "A key activity of the Central Union was to increase the sale of Latvian butter in foreign markets, highlighting the importance of agricultural exports to the economy.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "a special organisation for exporting dairy produce was established by the Government",
#     "explanation": "The government created a centralized share company, in which the Central Union was the main shareholder, to hold the sole rights for exporting dairy products.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "supplying them with dairy machinery",
#     "explanation": "The Central Union provided its member dairies with mechanical equipment, indicating a focus on improving the technological level of dairy processing.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "supplying them with... cattle fodder... fertilisers",
#     "explanation": "The cooperative union acted as a supplier of essential agricultural inputs like animal feed and fertilizers to its members, supporting primary production.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "equipped with modern machinery for pasteurizing and working up the large quantities of milk",
#     "explanation": "Refers to the use of up-to-date technology in a central facility to process large volumes of milk, signifying a move towards industrial-scale food production.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "worked up no less than 8,046,000 kilograms of milk and 569,000 kilograms of cream in 1934",
#     "explanation": "This statistic indicates the significant scale of raw milk and cream processing handled by the cooperative system, reflecting the high output of the dairy sector.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "a new chemical factory where various by-products such as casein, galalith... are manufactured",
#     "explanation": "The establishment of a factory to process dairy by-products demonstrates an effort to add value, diversify production, and reduce waste in the agricultural sector.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "advisory and educative character... staff of instructors, who visit the dairies... and give advice and instruction",
#     "explanation": "The Central Union provided educational services and practical guidance to rural dairies on production, management, and bookkeeping to improve their efficiency and standards.",
#     "subcategory": "Agricultural modernization"
#   }
# ]
# ```

# %% [markdown]
# ### Trying other models - finding middle ground between speed and accuracy
#
# Pro model provided accurate answer namely that there are no agricultural products in the text. However, it is not very fast and it is not very cheap to use. The above query cost us about 0.01 USD - that is 1 cent which might not seem like much, but if we want to analyze a large corpus of documents, the costs can add up quickly.
#
# So let's see if we can find a model that is faster and cheaper but still provides accurate results. We will try different models and see how they perform on our task.
#
# Let's try the `golden mean` as of today [Google Gemini 2.5 Flash](https://openrouter.ai/google/gemini-2.5-flash)
#
# To do so we simply provide the model name in the `get_openrouter_response` function.

# %%
# let's try with google/gemini-2.5-flash model
response = get_openrouter_response(agriculture_system_prompt, content, model="google/gemini-2.5-flash")
if response:
    print("Agriculture-related concepts extracted from the text using Gemini 2.5 Flash:")
    print(response)
# Out:
# Agriculture-related concepts extracted from the text using Gemini 2.5 Flash:
# []

# %% [markdown]
# ## Running model across multiple documents - our corpus
#
# The response looks good (and 10x cheaper that Gemini 2.5 Pro due mostly to limiting reasoning outputs which we do not need for concept mining task), however the question remains, what will happen when we run the model across multiple documents? Will have have many false positives or will the model be able to filter out the noise and provide us with relevant concepts?
#
# Now that we have gotten our results from a single document we can run the model across multiple documents in our corpus. We will iterate over the files in the directory where we extracted the LERQ corpus and apply the same system prompt to each file.
#
# Usually I like to run my prompts across a smaller sample than full corpus. So let's pick 30 documents at random from the corpus and see how the model performs.

# %%
# let's pick random 30 files from the corpus and run the model across them
def run_model_across_corpus(directory_path, system_prompt,
                            model="google/gemini-2.5-flash",
                            sample_size=30,
                            seed=2025,
                            verbose=True,
                            delay=0.1):
    """
    Run the model across a sample of files in the specified directory.

    :param directory_path: Path to the directory containing text files.
    :param system_prompt: The system prompt to guide the model's behavior.
    :param model: The model to use for the request (default is Gemini 2.5 Flash).
    :param sample_size: Number of files to sample from the directory.
    :return: List of responses from the model for each file.
    """
    from pathlib import Path
    from datetime import datetime
    import time
    from tqdm import tqdm  # for progress bar
    import random  # for random sampling

    directory = Path(directory_path)
    txt_files = list(directory.glob("**/*.txt"))  # Get all .txt files recursively

    if verbose:
        print(f"Found {len(txt_files)} text files in the directory {directory}.")

    if len(txt_files) < sample_size:
        print(f"Not enough files in the directory. Found {len(txt_files)} files, but requested {sample_size}.")
        return []

    if seed is not None:
        random.seed(seed) # this ensures reproducibility of the random sample
        # most random operations in computer science are not truly random, but rather pseudo-random

    sampled_files = random.sample(txt_files, sample_size)  # Randomly sample files
    responses = {} # we will use a dictionary to store responses with file names as keys

    for file in tqdm(sampled_files):
        with file.open('r', encoding='utf-8') as f:
            content = f.read()
        if verbose:
            now = datetime.now()
            # let's print the time in a human-readable format
            print(f"{now.strftime('%Y-%m-%d %H:%M:%S')}  Processing file: {file.name} ({file.stat().st_size:,} bytes)")

        response = get_openrouter_response(system_prompt, content, model=model)
        if response:
            responses[file.name] = response
        else:
            print(f"Failed to get a response for {file.name}")

        time.sleep(delay)  # Delay to avoid hitting API rate limits if necessary

    return responses

# %%
# what was our extract_dir again?
# we actually want the subdirectory with Latvian_Economic_Review folder
extract_dir = Path("data/Latvian_Economic_Review")  # Adjusted to point to the correct subdirectory
responses = run_model_across_corpus(extract_dir, agriculture_system_prompt,
                                    model="google/gemini-2.5-flash", # actually the default but let's be explicit
                                    sample_size=30, # again default is 30, but we can change it
                                    seed=2025, # specific seed for reproducibility
                                    verbose=False # set to True to see progress and processing information
                                    )
# Out:
# 100%|██████████| 30/30 [01:08<00:00,  2.28s/it]

# %% [markdown]
# ## Analyzing responses
#
# Now that we got 30 responses let's see if they are relevant and if the model was able to filter out the noise and provide us with relevant concepts.
#
# Main thing is to remember the format of our responses. Each response is a string in JSON format that contains the concepts extracted from the text. We have stored all responses in a dictionary with file name as key and response as value.

# %%
# how many responses do we have?
print(f"Got {len(responses)} responses from the model across the sampled files.")
# Out:
# Got 30 responses from the model across the sampled files.

# %%
# let's print the first 3 responses from our responses dictionary
for i, (file_name, response) in enumerate(responses.items()):
    if i < 3:  # Print only the first 3 responses
        print(f"File: {file_name}")
        print(f"Response: {response}\n")
    else:
        break
# Out:
# File: lerq1936s01n01_008_plaintext_s03.txt
# Response: [
#   {
#     "phrase": "flax monopoly",
#     "explanation": "A state-controlled system for the production, collection, and sale of flax, indicating government intervention in a specific agricultural commodity market.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "cultivation of flax",
#     "explanation": "Refers to the agricultural practice of growing flax, highlighting its suitability to the local soil and climate.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "growers' organisations",
#     "explanation": "Indicates the involvement and cooperation of farmer groups in the flax collection process.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "licensed flax collecting stations",
#     "explanation": "Designated points where flax is purchased from growers, part of the centralized collection system.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "monopoly warehouses in Riga",
#     "explanation": "Centralized storage facilities for flax, managed by the state monopoly, ensuring controlled inventory.",
#     "subcategory": "Grain storage and reserves"
#   },
#   {
#     "phrase": "grants loans to the licensed collectors to replenish their operative resources",
#     "explanation": "Financial assistance provided to collectors to support their operations, indicating a form of credit within the agricultural supply chain.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "sorting and grading of Latvian flax",
#     "explanation": "The process of classifying flax by quality and type, ensuring standardization for marketability.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "flax growing or flax exporting country",
#     "explanation": "Refers to countries involved in the cultivation and international trade of flax.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "water retted",
#     "explanation": "A specific method of processing flax fibers, involving soaking in water to separate the fibers.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "1934 crop",
#     "explanation": "Refers to the yield of flax harvested in a specific year, indicating a measure of agricultural output.",
#     "subcategory": "Crop yields"
#   },
#   {
#     "phrase": "flax for export is sold only f. o. b. Riga",
#     "explanation": "Specifies the terms of international trade for flax, indicating its role as an export commodity.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "store their flax in the warehouses of the monopoly section",
#     "explanation": "Allows buyers to store purchased flax in state-controlled facilities, indicating a storage service.",
#     "subcategory": "Grain storage and reserves"
#   }
# ]
#
# File: lerq1937s01n06_041_plaintext_s29.txt
# Response: []
#
# File: lerq1936s01n03_023_plaintext_s13.txt
# Response: []

# %%
# let's see if we got any responses at all meaning responses that are not [] or None
for file_name, response in responses.items():
    if response and response != "[]":
        print(f"File: {file_name} has a valid response.")
    else:
        print(f"File: {file_name} has no valid response.")
# Out:
# File: lerq1936s01n01_008_plaintext_s03.txt has a valid response.
# File: lerq1937s01n06_041_plaintext_s29.txt has no valid response.
# File: lerq1936s01n03_023_plaintext_s13.txt has no valid response.
# File: lerq1938s01n01_021_plaintext_s08.txt has a valid response.
# File: lerq1940s01n02_014_plaintext_s05.txt has a valid response.
# File: lerq1936s01n03_007_plaintext_s02.txt has a valid response.
# File: lerq1938s01n01_038_plaintext_s29.txt has no valid response.
# File: lerq1937s01n05_039_plaintext_s19.txt has a valid response.
# File: lerq1940s01n01_024_plaintext_s09.txt has a valid response.
# File: lerq1937s01n07_004_plaintext_s02.txt has a valid response.
# File: lerq1936s01n01_009_plaintext_s04.txt has no valid response.
# File: lerq1940s01n02_023_plaintext_s11.txt has a valid response.
# File: lerq1937s01n06_014_plaintext_s14.txt has a valid response.
# File: lerq1937s01n08_011_plaintext_s03.txt has a valid response.
# File: lerq1936s01n03_008_plaintext_s03.txt has no valid response.
# File: lerq1936s01n03_016_plaintext_s07.txt has no valid response.
# File: lerq1936s01n04_030_plaintext_s11.txt has a valid response.
# File: lerq1936s01n04_012_plaintext_s04.txt has a valid response.
# File: lerq1938s01n04_015_plaintext_s11.txt has a valid response.
# File: lerq1939s01n03_041_plaintext_s19.txt has no valid response.
# File: lerq1936s01n01_023_plaintext_s15.txt has no valid response.
# File: lerq1937s01n07_028_plaintext_s10.txt has no valid response.
# File: lerq1938s01n02_033_plaintext_s12.txt has a valid response.
# File: lerq1937s01n05_013_plaintext_s08.txt has a valid response.
# File: lerq1936s01n01_036_plaintext_s26.txt has a valid response.
# File: lerq1940s01n01_009_plaintext_s04.txt has a valid response.
# File: lerq1938s01n01_039_plaintext_s33.txt has no valid response.
# File: lerq1939s01n02_035_plaintext_s15.txt has a valid response.
# File: lerq1937s01n06_018_plaintext_s15.txt has no valid response.
# File: lerq1936s01n01_017_plaintext_s09.txt has no valid response.

# %%
# Let's get valid responses only and print them
valid_response = {}
for file_name, response in responses.items():
    if response and response != "[]":
        valid_response[file_name] = response
# how many valid responses do we have?
print(f"Got {len(valid_response)} valid responses from the model across the sampled files.")
# Out:
# Got 18 valid responses from the model across the sampled files.

# %%
# let's print first 3 valid responses
for i, (file_name, response) in enumerate(valid_response.items()):
    if i < 3:  # Print only the first 3 valid responses
        print(f"File: {file_name}")
        print(f"Response: {response}\n")
    else:
        break
# Out:
# File: lerq1936s01n01_008_plaintext_s03.txt
# Response: [
#   {
#     "phrase": "flax monopoly",
#     "explanation": "A state-controlled system for the production, collection, and sale of flax, indicating government intervention in a specific agricultural commodity market.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "cultivation of flax",
#     "explanation": "Refers to the agricultural practice of growing flax, highlighting its suitability to the local soil and climate.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "growers' organisations",
#     "explanation": "Indicates the involvement and cooperation of farmer groups in the flax collection process.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "licensed flax collecting stations",
#     "explanation": "Designated points where flax is purchased from growers, part of the centralized collection system.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "monopoly warehouses in Riga",
#     "explanation": "Centralized storage facilities for flax, managed by the state monopoly, ensuring controlled inventory.",
#     "subcategory": "Grain storage and reserves"
#   },
#   {
#     "phrase": "grants loans to the licensed collectors to replenish their operative resources",
#     "explanation": "Financial assistance provided to collectors to support their operations, indicating a form of credit within the agricultural supply chain.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "sorting and grading of Latvian flax",
#     "explanation": "The process of classifying flax by quality and type, ensuring standardization for marketability.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "flax growing or flax exporting country",
#     "explanation": "Refers to countries involved in the cultivation and international trade of flax.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "water retted",
#     "explanation": "A specific method of processing flax fibers, involving soaking in water to separate the fibers.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "1934 crop",
#     "explanation": "Refers to the yield of flax harvested in a specific year, indicating a measure of agricultural output.",
#     "subcategory": "Crop yields"
#   },
#   {
#     "phrase": "flax for export is sold only f. o. b. Riga",
#     "explanation": "Specifies the terms of international trade for flax, indicating its role as an export commodity.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "store their flax in the warehouses of the monopoly section",
#     "explanation": "Allows buyers to store purchased flax in state-controlled facilities, indicating a storage service.",
#     "subcategory": "Grain storage and reserves"
#   }
# ]
#
# File: lerq1938s01n01_021_plaintext_s08.txt
# Response: ```json
# [
#   {
#     "phrase": "first agricultural society in 1886",
#     "explanation": "Refers to the establishment of an organization focused on agricultural development and cooperation.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "first threshing machine society in 1888",
#     "explanation": "Indicates the formation of a cooperative for the shared use of agricultural machinery, specifically threshing machines.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "first cattle control society in 1901",
#     "explanation": "Suggests the creation of a cooperative focused on managing or improving livestock, likely related to breeding, health, or quality control.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "first co-operative dairy in 1909",
#     "explanation": "Marks the beginning of collective efforts in dairy production and processing.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "Riga Agricultural Central Society",
#     "explanation": "A central organization formed to disseminate agricultural knowledge and support agricultural societies.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "Agricultural societies 200",
#     "explanation": "Refers to the number of cooperative organizations dedicated to agricultural activities.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "Dairy societies 95",
#     "explanation": "Indicates the number of cooperative organizations involved in dairy production and processing.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "Agric. machine collective utilisation societies",
#     "explanation": "Societies formed for the shared use of agricultural machinery.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "dairy societies in Latvia are in an exceptionally favourable position. They have been so successful in their activities that they have practically won for themselves the monopoly in the producing of butter, cheese and other milk products, which are of such great importance in Latvia's agriculture and export trade.",
#     "explanation": "Highlights the significant success and market dominance of dairy cooperatives in Latvia, contributing substantially to agricultural exports.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "quantity of butter produced",
#     "explanation": "A direct measure of output from dairy production.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "rapid fall of butter prices which began in 1930, far from harming these co-operative societies, facilitated their reorganisation on sounder bases and enhanced the process of rationalising the production of butter.",
#     "explanation": "Describes how a price drop led to consolidation and efficiency improvements in butter production within dairy cooperatives.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "amalgamating the weaker societies, whose equipment was less up-to-date, with the larger societies in the same neighbourhood, thereby converting the smaller societies into ordinary milk receiving stations.",
#     "explanation": "Details a strategy for rationalizing dairy production by consolidating less efficient operations and modernizing the overall structure.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "mutual fire insurance societies operate principally in the countryside, where they undertake fire risks in respect of farm-houses, furniture, fittings, stock and other objects.",
#     "explanation": "Describes a form of rural cooperative insurance specifically for agricultural assets and property.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "agricultural societies",
#     "explanation": "General term for cooperative organizations focused on various aspects of agriculture.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "societies for the mutual use of machines",
#     "explanation": "Cooperative groups formed to share agricultural machinery.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "Latvian agricultural central union",
#     "explanation": "A central cooperative union supporting agricultural activities.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "Central union of Latvian co-operative dairy societies",
#     "explanation": "A central organization coordinating and supporting dairy cooperatives.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "especially in the sphere of agriculture which is the recognised basis of this country's welfare",
#     "explanation": "Highlights the fundamental importance of agriculture to the national economy and welfare.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "The establishment of the Latvian Chamber of Agriculture",
#     "explanation": "Refers to the creation of a governmental or semi-governmental body to oversee and promote agricultural interests and cooperative activities.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "non-profit-bearing agricultural societies",
#     "explanation": "New type of agricultural societies operating under the supervision of the Chamber of Agriculture, focused on non-commercial objectives.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "machine and technical department of the central union of Latvian co-operative dairy societies",
#     "explanation": "Indicates a specialized department within a dairy cooperative union focused on machinery and technical aspects, suggesting mechanization and technological adoption.",
#     "subcategory": "Mechanization of agriculture"
#   }
# ]
# ```
#
# File: lerq1940s01n02_014_plaintext_s05.txt
# Response: ```json
# [
#   {
#     "phrase": "productivity of Latvia's basic economic branch, — agriculture, is more independent of imports than other branches",
#     "explanation": "This highlights the foundational role of agriculture in Latvia's economy and its relative self-sufficiency regarding imports compared to other sectors.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "volume of production even in this field depends very much on the various auxiliary commodities required in agriculture which have to be imported from abroad, such as fertilisers, agricultural machinery, concentrated fodder, fuel, metals and so forth.",
#     "explanation": "This indicates that despite agriculture's independence in some aspects, its output is significantly reliant on imported inputs like fertilizers and machinery, suggesting a need for modernization and external resources.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "raw-material group includes a large proportion of the natural export goods produced by Latvian agriculture",
#     "explanation": "This points to agricultural products forming a significant part of Latvia's raw material exports, emphasizing the sector's contribution to foreign trade.",
#     "subcategory": "Agricultural exports"
#   }
# ]
# ```

# %% [markdown]
# ## Converting responses from JSON to Python dictionary
#
# Our LLM responses are formated as JSON strings, so we need to convert them to Python dictionaries and/or lists for easier manipulation and analysis. We can use the `json` module in Python to do this.

# %%
# let's go through all responses and convert them from JSON strings to Python data structures
# this will also be a good test on LLM output stability
import json
# let's convert all responses from JSON strings to Python data structures
converted_responses = {}
bad_responses = {}
for file_name, response in valid_response.items():
    try:
        converted_responses[file_name] = json.loads(response)  # Convert JSON string to Python data structure
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON for file {file_name}: {e}")
        bad_responses[file_name] = response

# let's print the first 3 converted responses
for i, (file_name, response) in enumerate(converted_responses.items()):
    if i < 3:  # Print only the first 3 converted responses
        print(f"File: {file_name}")
        print(f"Response: {response}\n")
    else:
        break
# Out:
# Error decoding JSON for file lerq1938s01n01_021_plaintext_s08.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1940s01n02_014_plaintext_s05.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1936s01n03_007_plaintext_s02.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1937s01n05_039_plaintext_s19.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1940s01n01_024_plaintext_s09.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1937s01n07_004_plaintext_s02.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1940s01n02_023_plaintext_s11.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1937s01n06_014_plaintext_s14.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1937s01n08_011_plaintext_s03.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1938s01n02_033_plaintext_s12.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1937s01n05_013_plaintext_s08.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1936s01n01_036_plaintext_s26.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1939s01n02_035_plaintext_s15.txt: Expecting value: line 1 column 1 (char 0)
# File: lerq1936s01n01_008_plaintext_s03.txt
# Response: [{'phrase': 'flax monopoly', 'explanation': 'A state-controlled system for the production, collection, and sale of flax, indicating government intervention in a specific agricultural commodity market.', 'subcategory': 'Agricultural exports'}, {'phrase': 'cultivation of flax', 'explanation': 'Refers to the agricultural practice of growing flax, highlighting its suitability to the local soil and climate.', 'subcategory': 'Other agricultural practices'}, {'phrase': "growers' organisations", 'explanation': 'Indicates the involvement and cooperation of farmer groups in the flax collection process.', 'subcategory': 'Peasant cooperatives'}, {'phrase': 'licensed flax collecting stations', 'explanation': 'Designated points where flax is purchased from growers, part of the centralized collection system.', 'subcategory': 'Other agricultural practices'}, {'phrase': 'monopoly warehouses in Riga', 'explanation': 'Centralized storage facilities for flax, managed by the state monopoly, ensuring controlled inventory.', 'subcategory': 'Grain storage and reserves'}, {'phrase': 'grants loans to the licensed collectors to replenish their operative resources', 'explanation': 'Financial assistance provided to collectors to support their operations, indicating a form of credit within the agricultural supply chain.', 'subcategory': 'Rural credit'}, {'phrase': 'sorting and grading of Latvian flax', 'explanation': 'The process of classifying flax by quality and type, ensuring standardization for marketability.', 'subcategory': 'Other agricultural practices'}, {'phrase': 'flax growing or flax exporting country', 'explanation': 'Refers to countries involved in the cultivation and international trade of flax.', 'subcategory': 'Agricultural exports'}, {'phrase': 'water retted', 'explanation': 'A specific method of processing flax fibers, involving soaking in water to separate the fibers.', 'subcategory': 'Other agricultural practices'}, {'phrase': '1934 crop', 'explanation': 'Refers to the yield of flax harvested in a specific year, indicating a measure of agricultural output.', 'subcategory': 'Crop yields'}, {'phrase': 'flax for export is sold only f. o. b. Riga', 'explanation': 'Specifies the terms of international trade for flax, indicating its role as an export commodity.', 'subcategory': 'Agricultural exports'}, {'phrase': 'store their flax in the warehouses of the monopoly section', 'explanation': 'Allows buyers to store purchased flax in state-controlled facilities, indicating a storage service.', 'subcategory': 'Grain storage and reserves'}]
#
# File: lerq1936s01n04_030_plaintext_s11.txt
# Response: [{'phrase': 'reclaiming this boggy district', 'explanation': 'Refers to the process of converting bogland into arable land suitable for cultivation, thereby expanding agricultural area.', 'subcategory': 'Other agricultural practices'}, {'phrase': 'enlarging our cultivable area', 'explanation': 'Indicates an effort to increase the total amount of land available for farming, suggesting a focus on agricultural expansion.', 'subcategory': 'Other agricultural practices'}, {'phrase': 'free to till Latvian soil for themselves', 'explanation': "Highlights the concept of self-sufficiency and national ownership over agricultural land, a direct benefit of the country's independence.", 'subcategory': 'Land reform'}]
#
# File: lerq1936s01n04_012_plaintext_s04.txt
# Response: [{'phrase': 'organising of agricultural, commercial and industrial censuses', 'explanation': 'Refers to the systematic collection of data for the agricultural sector, indicating an effort to understand and manage agricultural resources and output.', 'subcategory': 'Other agricultural practices'}, {'phrase': 'amortisation of capital invested in agriculture', 'explanation': 'Discusses the depreciation or write-off of financial investments made in the agricultural sector, which is relevant to rural credit and the financial health of farms.', 'subcategory': 'Rural credit'}, {'phrase': 'piece-work wages in agriculture', 'explanation': 'Refers to a specific payment method for labor in the agricultural sector, indicating aspects of rural labor economics.', 'subcategory': 'Other agricultural practices'}]

# %%
# let's print the bad responses
for file_name, response in bad_responses.items():
    print(f"File: {file_name} has a bad response: {response}")
# Out:
# File: lerq1938s01n01_021_plaintext_s08.txt has a bad response: ```json
# [
#   {
#     "phrase": "first agricultural society in 1886",
#     "explanation": "Refers to the establishment of an organization focused on agricultural development and cooperation.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "first threshing machine society in 1888",
#     "explanation": "Indicates the formation of a cooperative for the shared use of agricultural machinery, specifically threshing machines.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "first cattle control society in 1901",
#     "explanation": "Suggests the creation of a cooperative focused on managing or improving livestock, likely related to breeding, health, or quality control.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "first co-operative dairy in 1909",
#     "explanation": "Marks the beginning of collective efforts in dairy production and processing.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "Riga Agricultural Central Society",
#     "explanation": "A central organization formed to disseminate agricultural knowledge and support agricultural societies.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "Agricultural societies 200",
#     "explanation": "Refers to the number of cooperative organizations dedicated to agricultural activities.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "Dairy societies 95",
#     "explanation": "Indicates the number of cooperative organizations involved in dairy production and processing.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "Agric. machine collective utilisation societies",
#     "explanation": "Societies formed for the shared use of agricultural machinery.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "dairy societies in Latvia are in an exceptionally favourable position. They have been so successful in their activities that they have practically won for themselves the monopoly in the producing of butter, cheese and other milk products, which are of such great importance in Latvia's agriculture and export trade.",
#     "explanation": "Highlights the significant success and market dominance of dairy cooperatives in Latvia, contributing substantially to agricultural exports.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "quantity of butter produced",
#     "explanation": "A direct measure of output from dairy production.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "rapid fall of butter prices which began in 1930, far from harming these co-operative societies, facilitated their reorganisation on sounder bases and enhanced the process of rationalising the production of butter.",
#     "explanation": "Describes how a price drop led to consolidation and efficiency improvements in butter production within dairy cooperatives.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "amalgamating the weaker societies, whose equipment was less up-to-date, with the larger societies in the same neighbourhood, thereby converting the smaller societies into ordinary milk receiving stations.",
#     "explanation": "Details a strategy for rationalizing dairy production by consolidating less efficient operations and modernizing the overall structure.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "mutual fire insurance societies operate principally in the countryside, where they undertake fire risks in respect of farm-houses, furniture, fittings, stock and other objects.",
#     "explanation": "Describes a form of rural cooperative insurance specifically for agricultural assets and property.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "agricultural societies",
#     "explanation": "General term for cooperative organizations focused on various aspects of agriculture.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "societies for the mutual use of machines",
#     "explanation": "Cooperative groups formed to share agricultural machinery.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "Latvian agricultural central union",
#     "explanation": "A central cooperative union supporting agricultural activities.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "Central union of Latvian co-operative dairy societies",
#     "explanation": "A central organization coordinating and supporting dairy cooperatives.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "especially in the sphere of agriculture which is the recognised basis of this country's welfare",
#     "explanation": "Highlights the fundamental importance of agriculture to the national economy and welfare.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "The establishment of the Latvian Chamber of Agriculture",
#     "explanation": "Refers to the creation of a governmental or semi-governmental body to oversee and promote agricultural interests and cooperative activities.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "non-profit-bearing agricultural societies",
#     "explanation": "New type of agricultural societies operating under the supervision of the Chamber of Agriculture, focused on non-commercial objectives.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "machine and technical department of the central union of Latvian co-operative dairy societies",
#     "explanation": "Indicates a specialized department within a dairy cooperative union focused on machinery and technical aspects, suggesting mechanization and technological adoption.",
#     "subcategory": "Mechanization of agriculture"
#   }
# ]
# ```
# File: lerq1940s01n02_014_plaintext_s05.txt has a bad response: ```json
# [
#   {
#     "phrase": "productivity of Latvia's basic economic branch, — agriculture, is more independent of imports than other branches",
#     "explanation": "This highlights the foundational role of agriculture in Latvia's economy and its relative self-sufficiency regarding imports compared to other sectors.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "volume of production even in this field depends very much on the various auxiliary commodities required in agriculture which have to be imported from abroad, such as fertilisers, agricultural machinery, concentrated fodder, fuel, metals and so forth.",
#     "explanation": "This indicates that despite agriculture's independence in some aspects, its output is significantly reliant on imported inputs like fertilizers and machinery, suggesting a need for modernization and external resources.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "raw-material group includes a large proportion of the natural export goods produced by Latvian agriculture",
#     "explanation": "This points to agricultural products forming a significant part of Latvia's raw material exports, emphasizing the sector's contribution to foreign trade.",
#     "subcategory": "Agricultural exports"
#   }
# ]
# ```
# File: lerq1936s01n03_007_plaintext_s02.txt has a bad response: I am sorry, but the provided text does not contain any concepts related to Agriculture & Rural Economy. The text focuses exclusively on the shipping industry, freight rates, and the "Baltwhite Timber Scheme."
# File: lerq1937s01n05_039_plaintext_s19.txt has a bad response: ```json
# [
#   {
#     "phrase": "breeding of pigs for curing purposes",
#     "explanation": "Refers to the specialized raising of pigs specifically for bacon production, indicating a focus on quality and export standards.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "export slaughter house",
#     "explanation": "Facilities specifically designed and regulated for processing meat for international trade, highlighting the importance of export infrastructure.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "cooperative society Valmieras Export Slaughter House",
#     "explanation": "An example of a cooperative organization involved in the processing and export of agricultural products, demonstrating collective efforts in the rural economy.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "centralising this country's bacon export trade",
#     "explanation": "Efforts to consolidate and streamline the bacon export business, aiming for greater efficiency and control in international trade.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "control of export meat",
#     "explanation": "Government regulation and oversight of meat intended for export, ensuring quality and adherence to international standards.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "grain-fed pigs",
#     "explanation": "A specific agricultural practice related to animal feed, emphasizing its impact on the quality and consistency of the final product (bacon).",
#     "subcategory": "Other agricultural practices"
#   }
# ]
# ```
# File: lerq1940s01n01_024_plaintext_s09.txt has a bad response: ```json
# [
#   {
#     "phrase": "cattle fodder has there been no increase, there being a lack of fodder this year",
#     "explanation": "Indicates a shortage of animal feed, suggesting potential issues with livestock production or agricultural output in general.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "20% reduction for fertilisers from class 16 of the tariff has been rescinded",
#     "explanation": "The removal of a tariff reduction on fertilizers implies an increase in their cost, which could impact agricultural productivity and crop yields.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "goods of an agricultural character will enjoy the benefit of export tariffs in future. These are export butter, meat, grain and clover and timothy seeds, in respect of which the former reductions remain in force.",
#     "explanation": "Highlights specific agricultural products (butter, meat, grain, seeds) that continue to receive favorable export tariffs, indicating their importance in the national export strategy.",
#     "subcategory": "Agricultural exports"
#   }
# ]
# ```
# File: lerq1937s01n07_004_plaintext_s02.txt has a bad response: ```json
# [
#   {
#     "phrase": "cultivating the soil",
#     "explanation": "Refers to the long-standing practice of farming and crop production in Latvia.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "rapid increase in the different crops",
#     "explanation": "Indicates a significant growth in the variety and quantity of agricultural produce after the Great War.",
#     "subcategory": "Crop yields"
#   },
#   {
#     "phrase": "average crop per hectare in the last three years surpassed the pre-war yield by 30—40%",
#     "explanation": "Quantifies a substantial increase in agricultural output efficiency per unit of land.",
#     "subcategory": "Crop yields"
#   },
#   {
#     "phrase": "use of better seeds",
#     "explanation": "Highlights an improvement in agricultural inputs leading to higher productivity.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "employment of rational methods of farming and the institution of a well organised system of agronomical assistance",
#     "explanation": "Describes the adoption of efficient farming techniques and structured support for agricultural development.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "establishing of the Latvian Chamber of Agriculture",
#     "explanation": "Refers to the creation of a national body to promote and regulate agricultural interests.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "final fulfilment of the great agrarian reform",
#     "explanation": "Marks the completion of a significant land redistribution policy, ending large landholdings.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "conversion of dissatisfied landless elements into perfectly satisfied new farmers",
#     "explanation": "Describes the social impact of land reform, turning landless people into independent farmers.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "export of agricultural produce",
#     "explanation": "Highlights the critical role of agricultural goods in generating foreign currency for imports.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "pig-breeding has been organised on lines conducive to the production of bacon",
#     "explanation": "Describes a structured approach to livestock farming specifically for bacon production.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "providing valuable breeding material and helping farmers to establish special breeding stations",
#     "explanation": "Indicates state support for improving livestock genetics and infrastructure.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "careful selection of brood stock is made and the best specimens are registered in pedigree books",
#     "explanation": "Details a systematic approach to improving livestock quality through selective breeding and record-keeping.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "export of bacon and other meat products",
#     "explanation": "Refers to the trade of processed pork and other meats to foreign markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "A/S. 'Bekona Eksports', in whose hands the Latvian export of bacon and livestock is concentrated",
#     "explanation": "Identifies a central company responsible for managing and consolidating the export of bacon and live animals.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "export of live pigs has been increasing steadily",
#     "explanation": "Notes a consistent rise in the volume of live pig exports.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "export of Latvian butter has been increasing gradually",
#     "explanation": "Indicates a steady growth in the volume of butter sold to foreign markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "growth of this export was particularly rapid in the last three years",
#     "explanation": "Highlights an accelerated increase in butter exports during a specific period.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "stock farming, which is the basis of the dairy industry",
#     "explanation": "Emphasizes the foundational role of livestock raising in dairy production.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "number of milch cattle has been quadrupled",
#     "explanation": "Indicates a significant increase in the population of dairy cows.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "average yield of milk and its fat contents have increased still more substantially",
#     "explanation": "Points to improvements in the productivity and quality of milk per animal.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "quality of the livestock is watched over by special cattle control societies",
#     "explanation": "Describes organizations dedicated to monitoring and improving the genetic quality of cattle.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "export of pedigree cattle",
#     "explanation": "Refers to Latvia's transition from importing to exporting high-quality breeding livestock.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "Ministry of Agriculture promoted the amalgamation of the less successful dairy societies on the basis of mutual agreement",
#     "explanation": "Describes government-supported consolidation of dairy cooperatives to improve efficiency.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "export of butter has been organised on entirely new lines",
#     "explanation": "Indicates a significant restructuring of the butter export system.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "'Latvijas centralais sviesta eksports' (The United Butter Export of Latvia, Ltd.), was established for centralising all the butter export",
#     "explanation": "Identifies a new central company created to manage and consolidate all butter exports.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "company furthers the development and the output of the dairy industry",
#     "explanation": "Highlights the role of the central export company in promoting growth and production within the dairy sector.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "improve the quality of Latvian butter and to meet the special requirements of foreign markets",
#     "explanation": "Focuses on efforts to enhance product standards and tailor them to international demand.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "Dairy Produce Control Board",
#     "explanation": "Refers to a body responsible for overseeing and ensuring the quality of dairy products.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "export of cheese and eggs",
#     "explanation": "Refers to the trade of dairy and poultry products to foreign markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "organising and regulating this country's seed export trade",
#     "explanation": "Describes government efforts to structure and control the export of agricultural seeds.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "cultivation of clover, timothy and linseed",
#     "explanation": "Refers to the historical and ongoing practice of growing specific seed crops.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "A/S. 'Latvijas centralais seklu eksports', — a central company for exporting seeds from Latvia",
#     "explanation": "Identifies a centralized entity established to manage and streamline seed exports.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "company supplies farmers with grain seed and all other kinds of sowing material of the best quality",
#     "explanation": "Highlights the company's role in providing high-quality seeds to domestic farmers.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "cultivation of sugar-beet and vegetable seeds has been under the supervision of the company",
#     "explanation": "Indicates the company's oversight of specific seed crop production.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "seed cleansing establishment",
#     "explanation": "Refers to a facility equipped with modern machinery for purifying and processing seeds.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "export of potatoes and potato seed",
#     "explanation": "Refers to the trade of potatoes, including those specifically for planting, to foreign markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "regulating of the production of seed-potatoes is now completely in the hands of the company",
#     "explanation": "Indicates centralized control over the cultivation of potatoes specifically for use as seeds.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "special agreements are made with the farmers for producing seed-potatoes, in the same way as for sugar-beet and vegetable seeds",
#     "explanation": "Describes contractual arrangements with farmers to ensure specific production for seed purposes.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "organising the production and export of vetches and field peas, grain seed, linseed, meadow grass seed and vegetable seeds",
#     "explanation": "Details the company's role in managing the cultivation and international trade of various seeds.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "arrange the export of grain",
#     "explanation": "Refers to the successful initiation of grain exports by the government.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "grain bureau has exported 305,000 tons",
#     "explanation": "Quantifies the volume of grain exported by a government agency.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "buy up all the grain produced by the farmers and to pay prices which cover not only the cost of production but also the necessary outlays for the latest technical devices for augmenting the crops",
#     "explanation": "Describes a government policy of purchasing all farmer-produced grain at prices that encourage investment in modern farming technology.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "area under rye and that under wheat were enlarged by 9.2% and 30.6% respectively",
#     "explanation": "Indicates an expansion of land dedicated to specific grain crops.",
#     "subcategory": "Crop yields"
#   },
#   {
#     "phrase": "crop of rye increased accordingly by 33.1% and that of wheat by 28.7%",
#     "explanation": "Quantifies the increase in the yield of specific grain crops.",
#     "subcategory": "Crop yields"
#   },
#   {
#     "phrase": "peat litter are prepared for farmers' requirements",
#     "explanation": "Refers to the processing of peat for agricultural use, likely as bedding or soil amendment.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "Land Development Department, for instance, is solicitous for the surveying, amelioration and valuation of land",
#     "explanation": "Identifies a government department responsible for land management, improvement, and assessment.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "cultural-technical section is solicitous for the organisation and execution of all the work connected with the ameliorating of land",
#     "explanation": "Refers to a specialized section focused on improving agricultural land through technical and organizational means.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "regulating of rivers and the draining of land are carried out on the basis of carefully devised plans",
#     "explanation": "Describes planned efforts to manage water resources and improve land through drainage for agricultural purposes.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "supplying the farmers with drainage pipes at half price and paying 50% of the cost of railway transport",
#     "explanation": "Details government subsidies to farmers for land drainage infrastructure.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "cultivating of drained land is promoted by supplying the farmers with the necessary agricultural implements and placing the tractors of the Ministry of Agriculture at their disposal",
#     "explanation": "Describes government support for farming on improved land, including provision of tools and access to machinery.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "horticulture, horse breeding, sheep farming and pisciculture",
#     "explanation": "Lists various specialized agricultural activities beyond traditional crop and livestock farming.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "increasing the crops and improving prices in order to augment the income of the farmers",
#     "explanation": "Describes government strategies to boost agricultural output and ensure better financial returns for farmers.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "promote building activities in order to ensure personal comfort and convenience",
#     "explanation": "Refers to efforts to improve living conditions in rural areas through construction.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "encouraging farmers to build fireproof structures",
#     "explanation": "Indicates a policy to enhance safety in rural buildings, likely for agricultural structures or homes.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "Agronomical education also receives the attention it deserves. The network of agricultural schools, especially those with a two years' course of instruction, has been enlarged.",
#     "explanation": "Highlights the expansion of agricultural training and education facilities to improve farming knowledge and skills.",
#     "subcategory": "Agricultural modernization"
#   }
# ]
# ```
# File: lerq1940s01n02_023_plaintext_s11.txt has a bad response: ```json
# [
#   {
#     "phrase": "500 of which function in rural districts",
#     "explanation": "Refers to the significant presence and activity of mutual insurance societies specifically in rural areas.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "dense network of mutual insurance societies, numbering 557 all together and operating in all rural parishes",
#     "explanation": "Highlights the widespread establishment and operation of mutual insurance societies across rural regions, indicating a strong support system for the rural population.",
#     "subcategory": "Peasant cooperatives"
#   }
# ]
# ```
# File: lerq1937s01n06_014_plaintext_s14.txt has a bad response: I'm sorry, but I could not find any concepts related to "Agriculture & Rural Economy" in the provided text. The document focuses exclusively on the development of international and internal air traffic in Latvia during the 1930s.
# File: lerq1937s01n08_011_plaintext_s03.txt has a bad response: ```json
# [
#   {
#     "phrase": "Latvian farmers began to acquire landed property of their own",
#     "explanation": "This refers to the process where Latvian farmers gained ownership of land, indicating a shift in land tenure and potentially the impact of land reforms.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "advancement of dairying and stock farming",
#     "explanation": "This highlights efforts to improve and develop the dairy and livestock sectors of agriculture.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "co-operative dairies",
#     "explanation": "This indicates the formation of farmer-led organizations focused on dairy production and processing, aiming for collective economic benefit.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "butter export",
#     "explanation": "This points to the practice of selling butter to foreign markets, signifying a focus on agricultural products for international trade.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "agricultural organisation",
#     "explanation": "This refers to the structured management and planning of agricultural activities, possibly including farming practices, resource allocation, and market strategies.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "agrarian reform",
#     "explanation": "This refers to significant changes in land ownership and agricultural structures, often involving redistribution of land or changes in farming practices.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "upliftment of Latvian agriculture",
#     "explanation": "This signifies efforts to improve, modernize, and develop the agricultural sector in Latvia.",
#     "subcategory": "Agricultural modernization"
#   }
# ]
# ```
# File: lerq1938s01n02_033_plaintext_s12.txt has a bad response: ```json
# [
#   {
#     "phrase": "dairying",
#     "explanation": "Refers to the business of producing milk and dairy products.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "export of butter to foreign countries",
#     "explanation": "Indicates the sale of dairy products to international markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "breeding of valuable milch-cows",
#     "explanation": "Focuses on improving the genetic quality of dairy cattle for increased milk production.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "export large quantities of pedigree cattle to Russia",
#     "explanation": "Refers to the sale of high-quality breeding livestock to other countries.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "co-operative dairies",
#     "explanation": "Organizations where farmers pool resources for dairy production and processing.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "Central Union of Latvian Cooperative Dairy Societies",
#     "explanation": "A large cooperative organization established to promote economic and ideological cooperation among dairy farmers and manage butter export.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "control of export butter",
#     "explanation": "Government regulation and inspection of butter intended for export to ensure quality and standards.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "transport of butter in ice-cooled railway wagons, and on ships with cold storage",
#     "explanation": "Describes the use of refrigerated transport to maintain the quality of dairy products during shipment.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "durability test in respect of the keeping properties of Latvian butter",
#     "explanation": "A quality control measure to assess how well butter preserves over time.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "modern Government cold-storage plant situated in the Export Harbour of Riga",
#     "explanation": "A state-of-the-art facility for storing butter, likely for export, ensuring product quality.",
#     "subcategory": "Grain storage and reserves"
#   },
#   {
#     "phrase": "quality-mark 'Oak-Leaf'",
#     "explanation": "A branding or certification mark indicating high quality for Latvian butter in foreign markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "bottled pasteurized milk",
#     "explanation": "A method of processing and packaging milk for consumption, indicating modernization in dairy product preparation.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "Riga Milk Central",
#     "explanation": "A central organization for supplying fresh milk and dairy products to the city of Riga, founded by a cooperative union.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "strict grading of the milk and the fixing of prices, not only according to fat-contents, but also with respect to quality and cleanliness",
#     "explanation": "A system for evaluating milk based on multiple quality parameters, encouraging better production practices.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "total amount of full-milk produced",
#     "explanation": "Refers to the overall volume of milk production in the country.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "Central Union of Latvian Dairy Farmers",
#     "explanation": "A new, prominent organization aimed at furthering agricultural policy, promoting profitable exploitation of dairy products, and regulating the market.",
#     "subcategory": "Peasant cooperatives"
#   },
#   {
#     "phrase": "sole rights for exporting honey and eggs, as well as for exporting and providing the home market with dairy butter",
#     "explanation": "Exclusive control over the export and domestic supply of certain agricultural products, indicating state or cooperative control over markets.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "establishment of stations for the improvement of breeding cattle",
#     "explanation": "Initiatives to enhance the genetic quality and productivity of livestock.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "buy and to maintain all kinds of machines, implements and equipment for general use",
#     "explanation": "Refers to the acquisition and upkeep of agricultural machinery to support farming operations.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "provide their members, and the other inhabitants of their districts with the machines and implements necessary for cattle-breeding, dairying and farming",
#     "explanation": "Cooperatives supplying farmers with essential tools and machinery, promoting agricultural efficiency.",
#     "subcategory": "Mechanization of agriculture"
#   },
#   {
#     "phrase": "milk should be accepted according to the weight, fat contents and quality",
#     "explanation": "A system for purchasing milk based on its quantity and quality attributes, incentivizing better production.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "control the feeding and upkeep of the cattle, milking, and storage of the milk at the farms of their milk suppliers",
#     "explanation": "Oversight and regulation of farm practices to ensure the quality of milk production.",
#     "subcategory": "Other agricultural practices"
#   },
#   {
#     "phrase": "new system of paying premiums to farmers for milk of good quality, promptly delivered",
#     "explanation": "An incentive program to encourage farmers to produce high-quality milk and deliver it efficiently.",
#     "subcategory": "Rural credit"
#   }
# ]
# ```
# File: lerq1937s01n05_013_plaintext_s08.txt has a bad response: ```json
# [
#   {
#     "phrase": "agrarian reform and the conversion of villages into individual farms in Latgale",
#     "explanation": "This describes a significant land redistribution policy, changing land ownership from communal villages to private farms, particularly in the Latgale region.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "71,450 new farms were established in Latvia by 1935",
#     "explanation": "This indicates the large-scale creation of new agricultural units, a direct outcome of the land reform.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "4746 villages covering a total area of about 742,000 hectares had been divided into 72,679 new, individual farmsteads",
#     "explanation": "This provides specific data on the extent of land redistribution, showing the conversion of communal village land into numerous individual farms.",
#     "subcategory": "Land reform"
#   },
#   {
#     "phrase": "State credit for rural building operations",
#     "explanation": "This refers to government-provided loans specifically for construction in agricultural areas, indicating financial support for rural development.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "building requirements of rural artisans, existing farms of up to 27 hectares and public organisations",
#     "explanation": "This shows that rural credit was extended not only to new farms but also to existing smaller farms and rural craftspeople, supporting a broader rural economy.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "promote the building of fireproof houses and encourage farmers to erect neat, modern structures",
#     "explanation": "This highlights government efforts to improve the quality and safety of farm housing, suggesting a move towards modern agricultural infrastructure.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "fireproof country structures which are built in conformity with plans drafted or sanctioned by the Ministry of Agriculture, are released from paying a part of the loans received from the State",
#     "explanation": "This indicates a policy to incentivize modern, durable construction on farms by offering financial benefits for adherence to standardized plans approved by the agricultural ministry.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "State slate factory, which started work in spring 1936, supplies farmers with fireproof roofing material of the best quality at low cost",
#     "explanation": "This describes a state initiative to provide affordable, modern building materials to farmers, directly supporting agricultural infrastructure development.",
#     "subcategory": "Agricultural modernization"
#   },
#   {
#     "phrase": "Latvian Chamber of Agriculture and the agricultural faculty of the Latvian University",
#     "explanation": "This indicates the presence of institutions dedicated to the advancement and education in agriculture, suggesting a focus on agricultural development and research.",
#     "subcategory": "Agricultural modernization"
#   }
# ]
# ```
# File: lerq1936s01n01_036_plaintext_s26.txt has a bad response: ```json
# [
#   {
#     "phrase": "SEEDS EXPORT AND IMPORT",
#     "explanation": "Refers to the international trade of seeds, indicating agricultural products as a significant part of the economy.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "FLAX EXPORT",
#     "explanation": "Indicates the export of flax, a significant agricultural crop, showcasing its role in foreign trade.",
#     "subcategory": "Agricultural exports"
#   },
#   {
#     "phrase": "BUTTER AND EGGS EXPORT",
#     "explanation": "Refers to the export of dairy and poultry products, highlighting their importance in the country's trade balance.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "BACON EXPORT",
#     "explanation": "Refers to the export of processed pork products, indicating the significance of livestock production and its contribution to foreign trade.",
#     "subcategory": "Dairy and livestock production"
#   },
#   {
#     "phrase": "Valsts zemes banka",
#     "explanation": "A state land bank, likely involved in providing credit or managing land-related financial matters, potentially for agricultural purposes.",
#     "subcategory": "Rural credit"
#   },
#   {
#     "phrase": "Latvijas zemnieku kreditbanka",
#     "explanation": "A credit bank specifically for Latvian farmers, indicating a dedicated financial institution to support agricultural activities.",
#     "subcategory": "Rural credit"
#   }
# ]
# ```
# File: lerq1939s01n02_035_plaintext_s15.txt has a bad response: I'm sorry, but I cannot find any concepts related to Agriculture & Rural Economy in the provided text. The text primarily discusses the geological exploration and exploitation of natural resources in Latvia, such as minerals, peat, clay, and building stones, for industrial purposes. It does not mention agricultural practices, land reform, crop yields, or other related topics.

# %% [markdown]
# ### Fixing bad responses
#
# We see that bad responses are actually are not truly bad they just start with \```json and end with \```. We can fix this by removing the \```json and \``` from the start and end of the response string.

# %%
# let's go through all responses and convert them from JSON strings to Python dictionaries
# we will also strip the response from ```json and ``` at the start and end of the response string
good_responses = {}
bad_responses = {}
for file_name, response in responses.items():
    response = response.lstrip("```json")  # Remove ```json from the start
    response = response.rstrip("```")  # Remove ``` from the end
    try:
        good_responses[file_name] = json.loads(response)  # Convert JSON string to Python data structure
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON for file {file_name}: {e}")
        bad_responses[file_name] = response
# Out:
# Error decoding JSON for file lerq1936s01n03_007_plaintext_s02.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1937s01n06_014_plaintext_s14.txt: Expecting value: line 1 column 1 (char 0)
# Error decoding JSON for file lerq1939s01n02_035_plaintext_s15.txt: Expecting value: line 1 column 1 (char 0)

# %%
# let's print first bad responses again
for file_name, response in bad_responses.items():
    print(f"File: {file_name} has a bad response: {response}")
# Out:
# File: lerq1936s01n03_007_plaintext_s02.txt has a bad response: I am sorry, but the provided text does not contain any concepts related to Agriculture & Rural Economy. The text focuses exclusively on the shipping industry, freight rates, and the "Baltwhite Timber Scheme."
# File: lerq1937s01n06_014_plaintext_s14.txt has a bad response: I'm sorry, but I could not find any concepts related to "Agriculture & Rural Economy" in the provided text. The document focuses exclusively on the development of international and internal air traffic in Latvia during the 1930s.
# File: lerq1939s01n02_035_plaintext_s15.txt has a bad response: I'm sorry, but I cannot find any concepts related to Agriculture & Rural Economy in the provided text. The text primarily discusses the geological exploration and exploitation of natural resources in Latvia, such as minerals, peat, clay, and building stones, for industrial purposes. It does not mention agricultural practices, land reform, crop yields, or other related topics.

# %% [markdown]
# ### Fixing bad JSON
#
# We have gotten the easy cases fixed but the last malformed JSON is due to double quotes not being escaped properly in all places. We can fix this by replacing the double quotes with escaped double quotes.
#
# Alternatively we could apply stricter instructions to the model to return valid JSON. However, this would require us to adjust our system prompt and possibly the model parameters as well.
#
# We have a third option which is to supply the response to LLM again with different prompt and have LLM fix the JSON

# %%
# let's fix the malformed JSON responses
fix_json_prompt = """Please fix the following JSON response which should be an array of objects where double quotes are not escaped properly.
The response should be proper JSON string without ```json start and without ``` end with all other content intact."""
fixed_responses = {}
for file_name, response in bad_responses.items():
    # we will use the same get_openrouter_response function to fix the JSON
    fixed_response = get_openrouter_response(fix_json_prompt, response, model="google/gemini-2.5-flash")
    print(f"Fixed response for {file_name}: {fixed_response}")
    # try parsing response to ensure it is valid JSON
    try:
        json.loads(fixed_response)  # Validate the fixed response
    except json.JSONDecodeError as e:
        print(f"Error decoding fixed JSON for file {file_name}: {e}")
        fixed_response = None
    if fixed_response:
        fixed_responses[file_name] = fixed_response
    else:
        print(f"Failed to fix JSON for {file_name}")
# Out:
# Fixed response for lerq1936s01n03_007_plaintext_s02.txt: ```json
# [
#   {
#     "concept": "Shipping Industry",
#     "description": "The overarching industry discussed, encompassing all aspects of maritime transport."
#   },
#   {
#     "concept": "Freight Rates",
#     "description": "The cost charged by a carrier for transporting goods, a key economic indicator within the shipping industry."
#   },
#   {
#     "concept": "Baltwhite Timber Scheme",
#     "description": "A specific, named scheme related to the timber trade within the Baltic region, likely impacting shipping and freight."
#   }
# ]
# ```
# Error decoding fixed JSON for file lerq1936s01n03_007_plaintext_s02.txt: Expecting value: line 1 column 1 (char 0)
# Failed to fix JSON for lerq1936s01n03_007_plaintext_s02.txt
# Fixed response for lerq1937s01n06_014_plaintext_s14.txt: ```json
# [
#   {
#     "concept": "International Air Traffic",
#     "description": "Development of international air traffic in Latvia during the 1930s.",
#     "keywords": ["international", "air traffic", "Latvia", "1930s"]
#   },
#   {
#     "concept": "Internal Air Traffic",
#     "description": "Development of internal air traffic in Latvia during the 1930s.",
#     "keywords": ["internal", "air traffic", "Latvia", "1930s"]
#   }
# ]
# ```
# Error decoding fixed JSON for file lerq1937s01n06_014_plaintext_s14.txt: Expecting value: line 1 column 1 (char 0)
# Failed to fix JSON for lerq1937s01n06_014_plaintext_s14.txt
# Fixed response for lerq1939s01n02_035_plaintext_s15.txt: ```json
# [
#   {
#     "concept": "Geological Exploration",
#     "description": "The process of investigating the Earth's subsurface to identify and assess the presence of natural resources."
#   },
#   {
#     "concept": "Natural Resources Exploitation",
#     "description": "The extraction and utilization of natural resources, such as minerals, peat, clay, and building stones, for economic or industrial purposes."
#   },
#   {
#     "concept": "Industrial Purposes",
#     "description": "The application of resources or processes for manufacturing, production, or other industrial activities."
#   },
#   {
#     "concept": "Mineral Resources",
#     "description": "Naturally occurring inorganic solids with a definite chemical composition and crystal structure, often extracted for their economic value."
#   },
#   {
#     "concept": "Peat",
#     "description": "Accumulated decaying vegetation, often found in wetlands, used as fuel or in horticulture."
#   },
#   {
#     "concept": "Clay",
#     "description": "A fine-grained natural earthy material that is plastic when wet, used in ceramics, construction, and other industries."
#   },
#   {
#     "concept": "Building Stones",
#     "description": "Natural rocks or stones used as construction materials."
#   },
#   {
#     "concept": "Latvian Geology",
#     "description": "The study of the Earth's structure, composition, and processes specifically within the geographical area of Latvia."
#   }
# ]
# ```
# Error decoding fixed JSON for file lerq1939s01n02_035_plaintext_s15.txt: Expecting value: line 1 column 1 (char 0)
# Failed to fix JSON for lerq1939s01n02_035_plaintext_s15.txt

# %% [markdown]
# ## Running custom system prompt on specific folder
#
# Now that we have experimented with a small sample let's create a new function that takes the following parameters:
#
#
# - system_prompt - our custom instructions
# - file_folder where the files to be analyzed is needed
# - file_extension where we want .txt to be default extenstion
# - max_files where we want None to be default meaning unlimited files
# - seed where we want None to be default this would be used when max_files is not None
# - model where default would be "google/gemini-2.5-flash"
#
# We could add a few more parameters such as temperature and max tokens but this is enough to get started

# %%
# we want a function that will take our system prompt and file folder and will save in save_folder all responses using original file name and custom suffix
# - system_prompt - our custom instructions
# - file_folder where the files to be analyzed is needed
# - file_extension where we want .txt to be default extenstion
# - max_files where we want None to be default meaning unlimited files
# - seed where we want None to be default this would be used when max_files is not None
# - model where default would be "google/gemini-2.5-flash"
# - save_folder where default would be "responses"
# - we could specific save suffix but instead let's have a filename friendly version of model meaning we will remove / and - and replace those with _
import json
import os
import random
import time
from pathlib import Path
from datetime import datetime
from tqdm import tqdm

def save_responses_from_folder(system_prompt,
                               file_folder,
                               file_extension=".txt",
                               max_files=None,
                               seed=None,
                               model="google/gemini-2.5-flash",
                               save_folder="responses",
                               delay=0.1,
                               verbose=True):
    """
    Processes files in a folder using an LLM and saves the responses.

    :param system_prompt: The system prompt to guide the model's behavior.
    :param file_folder: Path to the directory containing files to process.
    :param file_extension: The extension of the files to process (default is .txt).
    :param max_files: Maximum number of files to process (default is None for all files).
    :param seed: Seed for random sampling if max_files is not None.
    :param model: The model to use for the request (default is google/gemini-2.5-flash).
    :param save_folder: The folder to save the responses (default is "responses").
    :param delay: Delay in seconds between API calls to avoid rate limits.
    :param verbose: If True, print detailed information during processing.
    """
    file_folder_path = Path(file_folder)
    save_folder_path = Path(save_folder)

    if not file_folder_path.exists():
        print(f"Error: File folder '{file_folder}' does not exist.")
        return

    # Create save folder if it doesn't exist
    save_folder_path.mkdir(parents=True, exist_ok=True)

    # Create a filename-friendly version of the model name
    model_suffix = model.replace("/", "_").replace("-", "_")

    # Find files with the specified extension
    all_files = sorted(file_folder_path.rglob(f"*{file_extension}"))

    if verbose:
        print(f"Found {len(all_files)} '{file_extension}' files in '{file_folder}'.")

    files_to_process = all_files
    if seed is not None and max_files is not None and max_files < len(all_files):
        random.seed(seed)
        files_to_process = random.sample(all_files, max_files)
        if verbose:
            print(f"Obtaining a random sample of {len(files_to_process)} files.")
    if seed is None and max_files is not None:
        files_to_process = files_to_process[:max_files]


    if verbose:
        print(f"Processing a  {len(files_to_process)} files.")

    if not files_to_process:
        print("No files to process.")
        return

    for file in tqdm(files_to_process, desc="Processing files"):
        if verbose:
            now = datetime.now()
            print(f"\n{now.strftime('%Y-%m-%d %H:%M:%S')}  Processing file: {file.relative_to(file_folder_path)} ({file.stat().st_size:,} bytes)")

        # Construct the output filename
        output_filename = save_folder_path / f"{file.stem}_{model_suffix}{file.suffix}"


        # Create parent directories for the output file if they don't exist
        output_filename.parent.mkdir(parents=True, exist_ok=True)

        # Check if response already exists
        if output_filename.exists():
            if verbose:
                print(f"  Response already exists for {file.name}, skipping.")
            continue


        with file.open('r', encoding='utf-8') as f:
            content = f.read()

        response = get_openrouter_response(system_prompt, content, model=model)

        # Save the response to a file
        with open(output_filename, 'w', encoding='utf-8') as outfile:
            outfile.write(response)
            if verbose:
                print(f"  Response saved to {output_filename}")

        time.sleep(delay)  # Pause between requests

    if verbose:
        print("\nFinished processing files.")

# %%
# let's get a folder that we want to process
# it would be data/Latvian_Economic_Review folder here
# for now let's only get 10 responses
source_folder = "data/Latvian_Economic_Review"
# now we can call the function using same old agriculture prompt
save_responses_from_folder(agriculture_system_prompt,
                           source_folder,
                           max_files = 10)
# Out:
# Found 419 '.txt' files in 'data/Latvian_Economic_Review'.
# Processing a  10 files.
# Processing files:   0%|          | 0/10 [00:00<?, ?it/s]
# 2025-08-07 13:36:17  Processing file: lerq1936s01n01_003_plaintext_s01.txt (8,662 bytes)
# Processing files:  10%|█         | 1/10 [00:05<00:47,  5.24s/it]
#   Response saved to responses/lerq1936s01n01_003_plaintext_s01_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:22  Processing file: lerq1936s01n01_006_plaintext_s02.txt (5,190 bytes)
# Processing files:  20%|██        | 2/10 [00:07<00:25,  3.24s/it]
#   Response saved to responses/lerq1936s01n01_006_plaintext_s02_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:24  Processing file: lerq1936s01n01_008_plaintext_s03.txt (6,066 bytes)
# Processing files:  30%|███       | 3/10 [00:11<00:27,  3.98s/it]
#   Response saved to responses/lerq1936s01n01_008_plaintext_s03_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:29  Processing file: lerq1936s01n01_009_plaintext_s04.txt (5,523 bytes)
# Processing files:  40%|████      | 4/10 [00:13<00:16,  2.83s/it]
#   Response saved to responses/lerq1936s01n01_009_plaintext_s04_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:30  Processing file: lerq1936s01n01_013_plaintext_s05.txt (3,866 bytes)
# Processing files:  50%|█████     | 5/10 [00:13<00:10,  2.16s/it]
#   Response saved to responses/lerq1936s01n01_013_plaintext_s05_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:31  Processing file: lerq1936s01n01_014_plaintext_s06.txt (1,144 bytes)
# Processing files:  60%|██████    | 6/10 [00:14<00:06,  1.70s/it]
#   Response saved to responses/lerq1936s01n01_014_plaintext_s06_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:32  Processing file: lerq1936s01n01_014_plaintext_s07.txt (629 bytes)
# Processing files:  70%|███████   | 7/10 [00:15<00:04,  1.41s/it]
#   Response saved to responses/lerq1936s01n01_014_plaintext_s07_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:33  Processing file: lerq1936s01n01_015_plaintext_s08.txt (7,520 bytes)
# Processing files:  80%|████████  | 8/10 [00:22<00:06,  3.24s/it]
#   Response saved to responses/lerq1936s01n01_015_plaintext_s08_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:40  Processing file: lerq1936s01n01_017_plaintext_s09.txt (951 bytes)
# Processing files:  90%|█████████ | 9/10 [00:23<00:02,  2.46s/it]
#   Response saved to responses/lerq1936s01n01_017_plaintext_s09_google_gemini_2.5_flash.txt
#
# 2025-08-07 13:36:41  Processing file: lerq1936s01n01_018_plaintext_s10.txt (7,625 bytes)
# Processing files: 100%|██████████| 10/10 [00:30<00:00,  3.09s/it]
#   Response saved to responses/lerq1936s01n01_018_plaintext_s10_google_gemini_2.5_flash.txt
#
# Finished processing files.

# %% [markdown]
# ## Adjusting system prompt for simpler output
#
# Now we see that sometimes instead of JSON we get nonstandard output.
#
# This presents a problem for automatic processing, so again we would need to write more code to catch these non standard situations or make our prompt even stronger or change our model.
#
# For now we will change prompt to be simpler and to produce simple CSV - comma separated values output

# %%
agriculture_system_prompt_list = """You are an expert assistant trained to analyze historical economic texts from 1930s Latvia.
Your task is to read the input document or paragraph and extract specific concepts related to **Agriculture & Rural Economy**.
Return the concepts as a list of single words enclosed in double quotes, each on a new line.
- Agricultural modernization return "modernization"
- Land reform return "reform"
- Crop yields return "yields"
- Agricultural exports return "exports"
- Collective farming return "collective"
- Peasant cooperatives return "cooperatives"
- Grain storage and reserves return "storage"
- Rural credit return "credit"
- Mechanization of agriculture return "mechanization"
- Dairy and livestock production return "dairy"

Example output:

"exports"
"modernization"
"reform"

If no relevant concept is found, return a single word "None" with quotes around it, like this: "None".


"""

# %%
my_prompt = """

"""
save_responses_from_folder(my_prompt,
                            source_folder,
                            max_files=30,  # let's limit to 10 files for now
                            save_folder="my_assignment",  # we will save to responses_list folder
                            model="google/gemini-2.5-flash", # using the same model as before
                            verbose=False)

# %%
# now let's run this function again with the new system prompt and extract to responses_csv folder
save_responses_from_folder(agriculture_system_prompt_list,
                            source_folder,
                            max_files=10,  # let's limit to 10 files for now
                            save_folder="responses_list",  # we will save to responses_list folder
                            model="google/gemini-2.5-flash", # using the same model as before
                            verbose=False)
# Out:
# Processing files: 100%|██████████| 10/10 [00:13<00:00,  1.32s/it]

# %% [markdown]
# Try it yourself by coming up with your own prompt!

# %%
# we can come up with our own prompt
my_custom_prompt = """
Change me!
"""
save_responses_from_folder(my_custom_prompt,
                            source_folder,
                            max_files=4,  # let's limit to 4 files for now
                            save_folder="workshop_exercise",  # we will save to responses_list folder
                            model="google/gemini-2.5-flash", # maybe change model?
                            verbose=False)
